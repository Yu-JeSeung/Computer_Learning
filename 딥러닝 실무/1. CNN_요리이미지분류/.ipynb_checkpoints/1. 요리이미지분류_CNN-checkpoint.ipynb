# %% [markdown]
# # 요리 이미지 분류_CNN

# %% [markdown]
# ### 요리 사진 판정 방법
# - 1) 사진에 어떤 요리가 있는지 판정 – 초밥, 샐러드, 마파두부 3종류의 요리 학습
# - 2) 판정한 요리의 칼로리를 출력

# %% [markdown]
# ### 요리 이미지 데이터 수집
# - 초밥, 샐러드, 마파두부 3가지 종류 요리 => 음식당 100장 이상의 사진 필요
# - Flickr 사이트 이용
#     - Flickr가 제공하는 사진검색 API를 사용하여 요리사진 수집
#     - 사이트 : https://www.flickr.com/

# %% [markdown]
# ## 1. Flickr API를 사용해 사진 수집하기

# %% [markdown]
# ### Flickr API를 사용해 사진 수집하기
# - 1) Yahoo.com 계정 만들기 http://yahoo.com
# - 2) Flickr API 계정 만들기 https://www.flickr.com/services/api/

# %% [markdown]
# ### Flickr API 모듈 설치하기

# %% [markdown]
# - pip install flickrapi

# %%
import os
os.getcwd()
# Out:
# 'D:\\한국경영인증원\\2021\\디지털핵심실무인재양성\\딥러닝\\소스코드\\딥러닝소스코드(수강생)\\CNN 프로젝트\\4. 요리이미지분류_CNN'

# %% [markdown]
# ### 1) Flickr API를 이용하여 원하는 음식 이미지 내려받기
# - 초밥, 샐러드, 마파두부 3가지 음식당 75X75 픽셀의 정사각형 이미지를 300개씩 내려 받기
# - ./image/sushi, ./image/salad, ./image/tofu 폴더 생성
# <img src="이미지다운로드.png">

# %%
# Flickr로 사진 검색해서 다운로드하기
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys

# AP 키 지정하기-
key = "89bbafccdb5c714c2b83c6d444b88f76"
secret = "86dc5f2cc8fed9bc"
wait_time = 1 # 대기 시간(초)

# Flickr API로 사진 검색하기 
def go_download(keyword, dir):  # go_download('초밥', 'sushi') 
    
    # 저장 경로 지정하기
    savedir = "./image/" + dir  # "./image/sushi" 
    
    # 디렉토리가 존재하지 않은 경우에만 디렉토리 생성
    if not os.path.exists(savedir):
        os.mkdir(savedir)
        
    # API를 사용해서 다운로드하기 
    flickr = FlickrAPI(key, secret, format='parsed-json')
    res = flickr.photos.search(
      text = keyword,     # 키워드
      per_page = 300,     # 검색할 개수
      media = 'photos',   # 사진 검색
      sort = "relevance", # 키워드 관련도 순서
      safe_search = 1,    # 안전 검색
      extras = 'url_q, license')
    
    # 결과 확인하기
    photos = res['photos']
    pprint(photos)
    
    try:
      # 1장씩 다운로드하기 
      for i, photo in enumerate(photos['photo']):
        url_q = photo['url_q']
        filepath = savedir + '/' + photo['id'] + '.jpg'
        if os.path.exists(filepath): continue
        print(str(i+1) + ":download=", url_q)
        urlretrieve(url_q, filepath)
        time.sleep(wait_time)
    except:
        import traceback
        traceback.print_exc()
        
# 키워드와 디렉터리 이름 지정해서 다운로드하기 
def main():
    go_download('초밥', 'sushi')
#     go_download('샐러드', 'salad')
#     go_download('마파두부', 'tofu')


# 메인 프로그램     
if __name__ == '__main__':
    main()
# Out:
# {'page': 1,
#  'pages': 3,
#  'perpage': 300,
#  'photo': [{'farm': 4,
#             'height_q': 150,
#             'id': '9599095698',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97325801@N04',
#             'secret': 'c30f68870b',
#             'server': '3769',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3769/9599095698_c30f68870b_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '9596303145',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97325801@N04',
#             'secret': 'f619c1ae2d',
#             'server': '5523',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/5523/9596303145_f619c1ae2d_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '9599095478',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97325801@N04',
#             'secret': 'a0fb4ddce1',
#             'server': '7361',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/7361/9599095478_a0fb4ddce1_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '9227638860',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '23344263@N07',
#             'secret': '5c3d5500d4',
#             'server': '3756',
#             'title': '남가 초밥',
#             'url_q': 'https://live.staticflickr.com/3756/9227638860_5c3d5500d4_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '33523410825',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '23344263@N07',
#             'secret': '052f8063ca',
#             'server': '2903',
#             'title': '#코스트코 #초밥',
#             'url_q': 'https://live.staticflickr.com/2903/33523410825_052f8063ca_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '115273651',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '67347235@N00',
#             'secret': '614e2ab73d',
#             'server': '55',
#             'title': '롯데마트에서 산 초밥',
#             'url_q': 'https://live.staticflickr.com/55/115273651_614e2ab73d_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4617258107',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '29180485@N07',
#             'secret': 'ebf9cce42a',
#             'server': '4040',
#             'title': '간만에 어머니랑 초밥!!!',
#             'url_q': 'https://live.staticflickr.com/4040/4617258107_ebf9cce42a_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '115273636',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '67347235@N00',
#             'secret': '8a2ca46d9f',
#             'server': '19',
#             'title': '또 다른 초밥',
#             'url_q': 'https://live.staticflickr.com/19/115273636_8a2ca46d9f_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2594339081',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'f137df97d7',
#             'server': '3004',
#             'title': '또 연어. 초밥 매니아~',
#             'url_q': 'https://live.staticflickr.com/3004/2594339081_f137df97d7_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2546508871',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'cf3f2e2b14',
#             'server': '2057',
#             'title': '또 초밥. 그런데, 장어가 ..',
#             'url_q': 'https://live.staticflickr.com/2057/2546508871_cf3f2e2b14_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8365544608',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': 'be87eb8700',
#             'server': '8512',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/8512/8365544608_be87eb8700_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2559638661',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'a96aba7ff1',
#             'server': '3010',
#             'title': '이번에는 초밥. 일주일 내내..',
#             'url_q': 'https://live.staticflickr.com/3010/2559638661_a96aba7ff1_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2272700235',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': '166301a38f',
#             'server': '2337',
#             'title': '나도 은근히 초밥 매니아.',
#             'url_q': 'https://live.staticflickr.com/2337/2272700235_166301a38f_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2198722277',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': '87b344dd50',
#             'server': '2012',
#             'title': '또 초밥. 진정한 음식 염장..',
#             'url_q': 'https://live.staticflickr.com/2012/2198722277_87b344dd50_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2538351058',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'f525f059d2',
#             'server': '2406',
#             'title': '또 초밥. 이정도면 초밥 좋..',
#             'url_q': 'https://live.staticflickr.com/2406/2538351058_f525f059d2_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8663734717',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '56298706@N00',
#             'secret': '079aee75ea',
#             'server': '8239',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/8239/8663734717_079aee75ea_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '15848906605',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': 'b71451c681',
#             'server': '8616',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/8616/15848906605_b71451c681_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3755325944',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '69fe7c8f64',
#             'server': '2472',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/2472/3755325944_69fe7c8f64_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4367100863',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '2ca73c7283',
#             'server': '2696',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/2696/4367100863_2ca73c7283_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4347508999',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': 'e7d1248bb4',
#             'server': '4050',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/4050/4347508999_e7d1248bb4_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '10170533083',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37934744@N02',
#             'secret': '6b01b6fa40',
#             'server': '3797',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3797/10170533083_6b01b6fa40_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6580102197',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37934744@N02',
#             'secret': '27031a08a1',
#             'server': '7141',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/7141/6580102197_27031a08a1_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5273893013',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37934744@N02',
#             'secret': 'c8cbb0006f',
#             'server': '5122',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/5122/5273893013_c8cbb0006f_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '13699444764',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '84404598@N02',
#             'secret': 'de9cf41488',
#             'server': '2821',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/2821/13699444764_de9cf41488_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4362282117',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '24675118@N08',
#             'secret': 'db551ecabf',
#             'server': '4064',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/4064/4362282117_db551ecabf_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4527613012',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '8335634@N07',
#             'secret': 'cd5ce1de6f',
#             'server': '4065',
#             'title': '아이랑 유부초밥 만들어요…',
#             'url_q': 'https://live.staticflickr.com/4065/4527613012_cd5ce1de6f_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2914638728',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '10633825@N04',
#             'secret': '4be4bb415d',
#             'server': '3005',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3005/2914638728_4be4bb415d_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2135461790',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'cee52a4b4f',
#             'server': '2231',
#             'title': '초밥!',
#             'url_q': 'https://live.staticflickr.com/2231/2135461790_cee52a4b4f_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3439852165',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'b765252ec7',
#             'server': '3324',
#             'title': '초밥!',
#             'url_q': 'https://live.staticflickr.com/3324/3439852165_b765252ec7_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3656988932',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '5559695d69',
#             'server': '3402',
#             'title': '초밥!!!',
#             'url_q': 'https://live.staticflickr.com/3402/3656988932_5559695d69_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '9313104038',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '98941613@N02',
#             'secret': 'e1c972ce44',
#             'server': '3781',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3781/9313104038_e1c972ce44_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '7378156626',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '79932701@N06',
#             'secret': '74a82f5837',
#             'server': '7092',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/7092/7378156626_74a82f5837_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317864',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': 'c67dacff6b',
#             'server': '164',
#             'title': '참치스시',
#             'url_q': 'https://live.staticflickr.com/164/364317864_c67dacff6b_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317858',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': '460dcce0e4',
#             'server': '102',
#             'title': '새우스시',
#             'url_q': 'https://live.staticflickr.com/102/364317858_460dcce0e4_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2473738908',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '24675118@N08',
#             'secret': 'd3f7113e4b',
#             'server': '3051',
#             'title': '桜エビ',
#             'url_q': 'https://live.staticflickr.com/3051/2473738908_d3f7113e4b_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317848',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': 'beef335422',
#             'server': '146',
#             'title': '롤',
#             'url_q': 'https://live.staticflickr.com/146/364317848_beef335422_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4350359859',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '47394853@N04',
#             'secret': '966474b3a6',
#             'server': '4047',
#             'title': '동생이 초밥을 사왔네 +_+',
#             'url_q': 'https://live.staticflickr.com/4047/4350359859_966474b3a6_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6154654495',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': 'be27713398',
#             'server': '6082',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/6082/6154654495_be27713398_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6854043060',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87808135@N00',
#             'secret': '286ac4700c',
#             'server': '6107',
#             'title': '토레토레 어시장',
#             'url_q': 'https://live.staticflickr.com/6107/6854043060_286ac4700c_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '4666293342',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '44632924@N05',
#             'secret': '39bf6d12da',
#             'server': '1276',
#             'title': '야근의 묘미 어쩐일로 이런 ..',
#             'url_q': 'https://live.staticflickr.com/1276/4666293342_39bf6d12da_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '7982241865',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '77515410@N08',
#             'secret': '2f88818874',
#             'server': '8311',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/8311/7982241865_2f88818874_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3962530402',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42993653@N07',
#             'secret': '0cbb1c4ef7',
#             'server': '3499',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3499/3962530402_0cbb1c4ef7_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6901616871',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '29180485@N07',
#             'secret': '44489a0124',
#             'server': '7210',
#             'title': '주말이니 동생님과 외식',
#             'url_q': 'https://live.staticflickr.com/7210/6901616871_44489a0124_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '5889913514',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '1c76a166b8',
#             'server': '6023',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/6023/5889913514_1c76a166b8_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6154639033',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '8332c2ede4',
#             'server': '6084',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/6084/6154639033_8332c2ede4_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4493093951',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '4',
#             'owner': '59658513@N00',
#             'secret': 'fd34a26f30',
#             'server': '2799',
#             'title': '맛있다옹',
#             'url_q': 'https://live.staticflickr.com/2799/4493093951_fd34a26f30_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5593852399',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29549416@N05',
#             'secret': 'f322052597',
#             'server': '5265',
#             'title': '2011.4.3',
#             'url_q': 'https://live.staticflickr.com/5265/5593852399_f322052597_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2738555364',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '305fdc0aa8',
#             'server': '3150',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3150/2738555364_305fdc0aa8_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317862',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': '7168bc5e1f',
#             'server': '157',
#             'title': '장어스시',
#             'url_q': 'https://live.staticflickr.com/157/364317862_7168bc5e1f_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '5736064865',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': 'c8b539852b',
#             'server': '2721',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/2721/5736064865_c8b539852b_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '142584175',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '77025408@N00',
#             'secret': '760162cc6a',
#             'server': '47',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/47/142584175_760162cc6a_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '9169305943',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '97692946@N06',
#             'secret': '455ce9b290',
#             'server': '5507',
#             'title': '_IGP1223',
#             'url_q': 'https://live.staticflickr.com/5507/9169305943_455ce9b290_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '9599095168',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97325801@N04',
#             'secret': '764fae3cd6',
#             'server': '7353',
#             'title': '스시히로바',
#             'url_q': 'https://live.staticflickr.com/7353/9599095168_764fae3cd6_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3076416085',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': 'c1a4a08d0f',
#             'server': '3061',
#             'title': '참치대뱃살 초밥',
#             'url_q': 'https://live.staticflickr.com/3061/3076416085_c1a4a08d0f_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6189625424',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '36877757@N05',
#             'secret': '5e1ea027d5',
#             'server': '6128',
#             'title': '간만의 초밥',
#             'url_q': 'https://live.staticflickr.com/6128/6189625424_5e1ea027d5_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3909359718',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29549416@N05',
#             'secret': '6979dc2298',
#             'server': '2461',
#             'title': '2009.9.10',
#             'url_q': 'https://live.staticflickr.com/2461/3909359718_6979dc2298_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3918842460',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '40384364@N03',
#             'secret': 'd4265ae1bb',
#             'server': '3508',
#             'title': '밥먹을때는 밥만먹어야죠.. ..',
#             'url_q': 'https://live.staticflickr.com/3508/3918842460_d4265ae1bb_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6782442058',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42778069@N06',
#             'secret': '3a35649d2c',
#             'server': '7063',
#             'title': '오늘 먹은 저녁 (1)',
#             'url_q': 'https://live.staticflickr.com/7063/6782442058_3a35649d2c_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '39323995851',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '139132837@N04',
#             'secret': 'eecc870764',
#             'server': '4734',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/4734/39323995851_eecc870764_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4042020925',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29549416@N05',
#             'secret': 'ca2135ccda',
#             'server': '2668',
#             'title': '2009.10.23',
#             'url_q': 'https://live.staticflickr.com/2668/4042020925_ca2135ccda_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6989443639',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '67347235@N00',
#             'secret': '81763bde42',
#             'server': '7051',
#             'title': '롯데마트 초밥',
#             'url_q': 'https://live.staticflickr.com/7051/6989443639_81763bde42_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4021363868',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': '489f288b45',
#             'server': '2429',
#             'title': '맛있다…',
#             'url_q': 'https://live.staticflickr.com/2429/4021363868_489f288b45_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '33354510381',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '152864136@N07',
#             'secret': 'e7944696ef',
#             'server': '3920',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3920/33354510381_e7944696ef_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4020572729',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': '0ba507c6fe',
#             'server': '2638',
#             'title': '맛있다.',
#             'url_q': 'https://live.staticflickr.com/2638/4020572729_0ba507c6fe_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2490681171',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'cb6b49ca00',
#             'server': '2289',
#             'title': '이럴수가! 장어가 없어!',
#             'url_q': 'https://live.staticflickr.com/2289/2490681171_cb6b49ca00_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6782443630',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42778069@N06',
#             'secret': 'ca3061a805',
#             'server': '7194',
#             'title': '오늘 먹은 저녁 (1)',
#             'url_q': 'https://live.staticflickr.com/7194/6782443630_ca3061a805_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '42050638502',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '156630706@N03',
#             'secret': '23c2f486c1',
#             'server': '977',
#             'title': '꼬지 맛있쪙',
#             'url_q': 'https://live.staticflickr.com/977/42050638502_23c2f486c1_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3254839090',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '30255546@N02',
#             'secret': '666d9342f8',
#             'server': '3122',
#             'title': 'Soybean Curd with Rice (유부 초밥=YuBu ChoBap)',
#             'url_q': 'https://live.staticflickr.com/3122/3254839090_666d9342f8_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3883965190',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '41687858@N08',
#             'secret': '1ff82734c7',
#             'server': '2593',
#             'title': '초밥 먹으러 왔어요~',
#             'url_q': 'https://live.staticflickr.com/2593/3883965190_1ff82734c7_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35865964001',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '135405619@N07',
#             'secret': 'e455d21ea8',
#             'server': '4297',
#             'title': 'Sushi',
#             'url_q': 'https://live.staticflickr.com/4297/35865964001_e455d21ea8_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '14604999840',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '126415358@N06',
#             'secret': '74b0142c01',
#             'server': '5586',
#             'title': '#초밥#스시#sushi#노량진#먹스타그램',
#             'url_q': 'https://live.staticflickr.com/5586/14604999840_74b0142c01_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '45770243534',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '127701072@N05',
#             'secret': 'dbdfd6e7c7',
#             'server': '4864',
#             'title': 'Sushi, Japan',
#             'url_q': 'https://live.staticflickr.com/4864/45770243534_dbdfd6e7c7_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2778892153',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '39117859@N00',
#             'secret': '38a329ae7b',
#             'server': '3076',
#             'title': 'Delicious Sushi/초밥',
#             'url_q': 'https://live.staticflickr.com/3076/2778892153_38a329ae7b_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '15059178752',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '54687792@N06',
#             'secret': '49b3e4a978',
#             'server': '3843',
#             'title': '유부 초밥',
#             'url_q': 'https://live.staticflickr.com/3843/15059178752_49b3e4a978_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2779748226',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '39117859@N00',
#             'secret': '6cd432f238',
#             'server': '3083',
#             'title': 'School Sushi/초밥',
#             'url_q': 'https://live.staticflickr.com/3083/2779748226_6cd432f238_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2595948649',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '12608639@N03',
#             'secret': '9c82ba2225',
#             'server': '3287',
#             'title': 'Tamago sushi',
#             'url_q': 'https://live.staticflickr.com/3287/2595948649_9c82ba2225_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8321083556',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '91629146@N02',
#             'secret': '82fb4e703e',
#             'server': '8501',
#             'title': 'Sushi 초밥',
#             'url_q': 'https://live.staticflickr.com/8501/8321083556_82fb4e703e_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '14615751310',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '126415358@N06',
#             'secret': '7d8d76e625',
#             'server': '3924',
#             'title': '#가로수길 #세로수길 #갓덴스시 #회전초밥 #초밥 #회 #먹스타그램',
#             'url_q': 'https://live.staticflickr.com/3924/14615751310_7d8d76e625_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '7987365371',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '54782710@N07',
#             'secret': '8d1fc45bf2',
#             'server': '8456',
#             'title': '간단하게 초밥',
#             'url_q': 'https://live.staticflickr.com/8456/7987365371_8d1fc45bf2_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35159195444',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '135405619@N07',
#             'secret': '17e30a35b0',
#             'server': '4323',
#             'title': 'Sushi',
#             'url_q': 'https://live.staticflickr.com/4323/35159195444_17e30a35b0_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '15060206075',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '54687792@N06',
#             'secret': 'd308c2a9af',
#             'server': '5563',
#             'title': '회전 초밥',
#             'url_q': 'https://live.staticflickr.com/5563/15060206075_d308c2a9af_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '8166677899',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '63167781@N07',
#             'secret': '2b6ede58c1',
#             'server': '7118',
#             'title': '다미진횟집 초밥',
#             'url_q': 'https://live.staticflickr.com/7118/8166677899_2b6ede58c1_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '8958258251',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11238204@N08',
#             'secret': '056314225d',
#             'server': '7334',
#             'title': '초밥 수업',
#             'url_q': 'https://live.staticflickr.com/7334/8958258251_056314225d_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '15057173931',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '54687792@N06',
#             'secret': '276db17967',
#             'server': '3851',
#             'title': '회전 초밥',
#             'url_q': 'https://live.staticflickr.com/3851/15057173931_276db17967_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5348422111',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50650870@N02',
#             'secret': '6f74e2735c',
#             'server': '5250',
#             'title': '연어 초밥 @ 스시앤스시',
#             'url_q': 'https://live.staticflickr.com/5250/5348422111_6f74e2735c_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '15060206165',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '54687792@N06',
#             'secret': 'b36174ffab',
#             'server': '3864',
#             'title': '회전 초밥',
#             'url_q': 'https://live.staticflickr.com/3864/15060206165_b36174ffab_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5348410141',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50650870@N02',
#             'secret': '2336ba3142',
#             'server': '5130',
#             'title': '멍게 초밥 @ 스시앤스시',
#             'url_q': 'https://live.staticflickr.com/5130/5348410141_2336ba3142_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35610026690',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '135405619@N07',
#             'secret': 'd0e59863a4',
#             'server': '4309',
#             'title': 'Sushi',
#             'url_q': 'https://live.staticflickr.com/4309/35610026690_d0e59863a4_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35828039922',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '135405619@N07',
#             'secret': 'a883bfc176',
#             'server': '4299',
#             'title': 'Sushi',
#             'url_q': 'https://live.staticflickr.com/4299/35828039922_a883bfc176_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2785815174',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '48432348@N00',
#             'secret': '36c7a987db',
#             'server': '3234',
#             'title': '비도 오는데, 내가 좋아하는..',
#             'url_q': 'https://live.staticflickr.com/3234/2785815174_36c7a987db_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2627082961',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '15134851@N00',
#             'secret': '9c66c6666b',
#             'server': '3165',
#             'title': '가족과 함께 스타피쉬에서 외..',
#             'url_q': 'https://live.staticflickr.com/3165/2627082961_9c66c6666b_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3775320116',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'a0297feceb',
#             'server': '3440',
#             'title': '초밥이 이정도는 돼야지. 오..',
#             'url_q': 'https://live.staticflickr.com/3440/3775320116_a0297feceb_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '50753685703',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': 'feaea1eb80',
#             'server': '65535',
#             'title': '초밥 Sushi',
#             'url_q': 'https://live.staticflickr.com/65535/50753685703_feaea1eb80_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '22878598231',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '130554307@N07',
#             'secret': '83a22cefb8',
#             'server': '5745',
#             'title': '마더와 초밥.',
#             'url_q': 'https://live.staticflickr.com/5745/22878598231_83a22cefb8_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8166708948',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '63167781@N07',
#             'secret': 'fe7f04bfa3',
#             'server': '8198',
#             'title': '다미진횟집 초밥',
#             'url_q': 'https://live.staticflickr.com/8198/8166708948_fe7f04bfa3_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4914047837',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '8826bb79fb',
#             'server': '4119',
#             'title': '정어리 초밥(이와시)',
#             'url_q': 'https://live.staticflickr.com/4119/4914047837_8826bb79fb_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6854043222',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87808135@N00',
#             'secret': '9a56518b78',
#             'server': '6240',
#             'title': '토레토레 어시장',
#             'url_q': 'https://live.staticflickr.com/6240/6854043222_9a56518b78_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35188178103',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '135405619@N07',
#             'secret': 'e72be1bfb4',
#             'server': '4307',
#             'title': 'Sushi',
#             'url_q': 'https://live.staticflickr.com/4307/35188178103_e72be1bfb4_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4979210264',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': 'a277e44e82',
#             'server': '4108',
#             'title': '유부 초밥',
#             'url_q': 'https://live.staticflickr.com/4108/4979210264_a277e44e82_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6920226753',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29565988@N04',
#             'secret': 'b667236ece',
#             'server': '7199',
#             'title': '간만에 초밥 먹는다해',
#             'url_q': 'https://live.staticflickr.com/7199/6920226753_b667236ece_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5371585020',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '27133654@N06',
#             'secret': '5265bd79b1',
#             'server': '5084',
#             'title': '헉 초밥',
#             'url_q': 'https://live.staticflickr.com/5084/5371585020_5265bd79b1_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '49882601867',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '2f267e0059',
#             'server': '65535',
#             'title': '초밥 Sushi',
#             'url_q': 'https://live.staticflickr.com/65535/49882601867_2f267e0059_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4351080075',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license':
# 251:download= https://live.staticflickr.com/6082/6065237370_3cb631ac66_q.jpg
# 252:download= https://live.staticflickr.com/1066/4725829569_4a52755c48_q.jpg
# 253:download= https://live.staticflickr.com/2776/4328699865_c28a13a958_q.jpg
# 254:download= https://live.staticflickr.com/2684/4329597665_25fac3a135_q.jpg
# 255:download= https://live.staticflickr.com/7015/6520363367_5b51f47629_q.jpg
# 256:download= https://live.staticflickr.com/4055/4628476332_e48ba7790a_q.jpg
# 257:download= https://live.staticflickr.com/6136/5969355466_781cf82c5a_q.jpg
# 258:download= https://live.staticflickr.com/5180/29838111476_fa514abd0a_q.jpg
# 259:download= https://live.staticflickr.com/3482/3990237534_ef9de17437_q.jpg
# 260:download= https://live.staticflickr.com/3858/15037201816_a10dbb42e3_q.jpg
# 261:download= https://live.staticflickr.com/5224/5605263373_792bf22fca_q.jpg
# 262:download= https://live.staticflickr.com/7023/6515305809_6b62a8c61f_q.jpg
# 263:download= https://live.staticflickr.com/4029/4547255821_e512e0682a_q.jpg
# 264:download= https://live.staticflickr.com/4102/4875357400_4e52fb1b1c_q.jpg
# 265:download= https://live.staticflickr.com/2602/4127842558_75635c6474_q.jpg
# 266:download= https://live.staticflickr.com/6009/5968797541_4672ee219e_q.jpg
# 267:download= https://live.staticflickr.com/8469/8108114335_c1d8ca5f43_q.jpg
# 268:download= https://live.staticflickr.com/7415/9336975354_c368b316ab_q.jpg
# 269:download= https://live.staticflickr.com/4014/4328686933_27a972c3f4_q.jpg
# 270:download= https://live.staticflickr.com/5199/7385755830_879451ae7c_q.jpg
# 271:download= https://live.staticflickr.com/2275/2202815273_7a86092f75_q.jpg
# 272:download= https://live.staticflickr.com/8211/8325075878_5624d22b66_q.jpg
# 273:download= https://live.staticflickr.com/5505/14333718982_6c89a2d564_q.jpg
# 274:download= https://live.staticflickr.com/8679/16469809042_96722099d4_q.jpg
# 275:download= https://live.staticflickr.com/4002/4627884961_03619c5ddf_q.jpg
# 276:download= https://live.staticflickr.com/3586/4627867141_ea83f5bf8c_q.jpg
# 277:download= https://live.staticflickr.com/2777/4270688277_7cc61f3522_q.jpg
# Traceback (most recent call last):
#   File "C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_33720/3704077452.py", line 44, in go_download
#     time.sleep(wait_time)
# KeyboardInterrupt

# %% [markdown]
# ### 2) 클리닝 - 관계없는 사진 제거하기
# - 제대로 된 사진 100개만 남기기
# - 대상이 크게 나오고 다른 물체가 안나오고 색이 선명한 것 위주로 선택
# - 필터를 심하게 적용해 색상이 이상하거나 흑백 이미지는 제거

# %%
# 디렉토리 안의 이미지 파일 수 확인하기
import os, glob

path1 = "./image/salad/"
path2 = "./image/sushi/"
path3 = "./image/tofu/"

file = glob.glob(path1 + "/*.jpg")
               
# print("salad: ", len(glob.glob(path1 + "/*.jpg")))
# print("sushi: ", len(glob.glob(path2 + "/*.jpg")))
# print("tofu: ", len(glob.glob(path3 + "/*.jpg")))
# Out:
# %% [markdown]
# ### 3) 디렉토리 내부의 이미지를 Numpy 형식으로 합치기
# - 요리 사진을 데이터 셋으로 활용할 수 있게 Numpy 형식으로 변환하여 파일로 저장
# - 요리 이미지가 컬러 이미지이므로 RGB 컬러로 변환
# - 요리 이미지 크기를 32 X 32로 변환
# - RBG의 각 색상 값을 0~1까지의 실수로 변환
# - image 디렉토리에 photos.npz 라는 Numpy  형식의 파일 생성
# - 요리 레이블
#     - 0 : 초밥, 1 : 샐러드, 2 : 마파두부

# %%
# 이미지들을 NumPy 형식으로 변환하기
import numpy as np
from PIL import Image
import os, glob, random

outfile = "image/photos.npz" # 저장할 파일 이름
max_photo = 100 # 사용할 이미지 수
photo_size = 32 # 이미지 크기
x = [] # 이미지 데이터
y = [] # 레이블 데이터

# path 내부의 이미지 읽어 들이기 
def glob_files(path, label):        # glob_files("./image/sushi", 0)
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    
    # 파일 처리하기
    num = 0
    for f in files:
        if num >= max_photo: break
        num += 1
        # 이미지 파일 읽어 들이기
        img = Image.open(f)
        img = img.convert("RGB") # 색공간 변환하기
        img = img.resize((photo_size, photo_size)) # 크기 변경하기
        img = np.asarray(img) #RBG의 각 색상 값을 0~1까지의 실수로 변환
        x.append(img)
        y.append(label)
        
def main():
    
    # 디렉터리 읽어 들이기 
    glob_files("./image/sushi", 0)
    glob_files("./image/salad", 1)
    glob_files("./image/tofu", 2)
    
    # 파일로 저장하기 
    np.savez(outfile, x=x, y=y)
    print("저장했습니다:" + outfile, len(x))

# 메인 프로그램     
if __name__ == '__main__':
    main()
# Out:
# 저장했습니다:image/photos.npz 253

# %%
# import numpy as np
# from PIL import Image
# import os, glob, random
# import matplotlib.pyplot as plt

# f = './image/salad\\2712900692.jpg'
# img = Image.open(f)
# # plt.imshow(img)
# img = img.convert("RGB") # 색공간 변환하기
# # plt.imshow(img)
# img = img.resize((32, 32)) # 크기 변경하기
# # plt.imshow(img)
# img = np.asarray(img) #RBG의 각 색상 값을 0~1까지의 실수로 변환
# print(img)
# Out:
# [[[194 179 179]
#   [193 180 179]
#   [193 181 177]
#   ...
#   [182 167 155]
#   [180 171 170]
#   [170 167 167]]
#
#  [[194 179 178]
#   [192 181 180]
#   [192 184 183]
#   ...
#   [185 166 151]
#   [180 165 150]
#   [164 156 131]]
#
#  [[192 185 188]
#   [195 190 195]
#   [193 191 196]
#   ...
#   [185 168 151]
#   [181 166 145]
#   [156 149 113]]
#
#  ...
#
#  [[159 157 183]
#   [218 219 224]
#   [249 255 253]
#   ...
#   [129 120 118]
#   [130 118 112]
#   [130 117 108]]
#
#  [[185 185 210]
#   [146 144 172]
#   [189 191 203]
#   ...
#   [129 117 110]
#   [129 116 108]
#   [130 117 110]]
#
#  [[247 249 249]
#   [195 194 213]
#   [139 135 162]
#   ...
#   [130 116 109]
#   [130 117 108]
#   [131 118 112]]]

# %% [markdown]
# ### 4) 이미지 목록 확인하기

# %%
import matplotlib.pyplot as plt
import numpy as np

# 사진 데이타 읽어 들이기
photos = np.load("image/photos.npz")
x = photos["x"]
y = photos["y"]

# 시작 인덱스 
idx = 200  # 100 or 200으로 변경하여 다른 이미지도 확인하기

# pyplot으로 출력하기
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])
    
plt.show()

# %%
# 시작 인덱스
idx = 100  # 100 or 200으로 변경하여 다른 이미지도 확인하기

# pyplot으로 출력하기
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])
    
plt.show()

# %%
# 시작 인덱스
idx = 200  # 100 or 200으로 변경하여 다른 이미지도 확인하기

# pyplot으로 출력하기
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])
    
plt.show()

# %% [markdown]
# ### 5) CNN 모델 만들기 => "cnn_model.py"로 저장

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam

# CNN 모델 정의하기
def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', 
                     input_shape=in_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
    return model

# 컴파일하고 모델 반환하기
def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss='categorical_crossentropy',
        optimizer = Adam(1e-4),
        metrics=['accuracy'])
    return model

# %% [markdown]
# ### 6) CNN 모델을 사용하여 학습 시키기
# - 주피터에서 [Kernel --> Restart] 클릭하여 커널을 재시작한 후 실행
# - 정답률이 너무 안좋은 경우는 이미지 클리닝을 한 후 다시 실행하기

# %% [markdown]
# ### (1) 학습 데이타 + 테스트 데이타 분리하여 학습

# %%
import cnn_model  # 내가 만든 CNN 모델 import
import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# 입력과 출력 지정하기 
im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color) # (32, 32, 3)
nb_classes = 3 # 레이블 수

# 사진 데이터 읽어 들이기 
photos = np.load('image/photos.npz')
x = photos['x']
y = photos['y']

# X 속성 데이터를 1차원에서 3차원 배열로 변환 + 정규화하기 
x = x.reshape(-1, im_rows, im_cols, im_color)
x = x.astype('float32') / 255

# Y 레이블을 One-hot 형식으로 변환하기 
y = to_categorical(y.astype('int32'), nb_classes)

# 학습 전용과 테스트 전용으로 구분하기 
x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                    test_size=0.2,
                                                   random_state=777)
# 검증 데이타 만들기
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, 
                                                  test_size=0.2,
                                                  random_state=777)

# CNN 모델 만들기 
model = cnn_model.get_model(in_shape, nb_classes)

# 학습 실행하기 
hist = model.fit(x_train, y_train,
          batch_size=32,
          epochs=20,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 7/7 [==============================] - 1s 137ms/step - loss: 1.0674 - accuracy: 0.4109 - val_loss: 1.0732 - val_accuracy: 0.3137
# Epoch 2/20
# 7/7 [==============================] - 1s 92ms/step - loss: 1.0463 - accuracy: 0.4406 - val_loss: 1.0693 - val_accuracy: 0.2941
# Epoch 3/20
# 7/7 [==============================] - 1s 105ms/step - loss: 1.0345 - accuracy: 0.4802 - val_loss: 1.0643 - val_accuracy: 0.3137
# Epoch 4/20
# 7/7 [==============================] - 1s 103ms/step - loss: 1.0647 - accuracy: 0.3564 - val_loss: 1.0613 - val_accuracy: 0.3333
# Epoch 5/20
# 7/7 [==============================] - 1s 108ms/step - loss: 1.0254 - accuracy: 0.4554 - val_loss: 1.0591 - val_accuracy: 0.3725
# Epoch 6/20
# 7/7 [==============================] - 1s 94ms/step - loss: 1.0461 - accuracy: 0.4158 - val_loss: 1.0540 - val_accuracy: 0.4510
# Epoch 7/20
# 7/7 [==============================] - 1s 106ms/step - loss: 1.0430 - accuracy: 0.4455 - val_loss: 1.0541 - val_accuracy: 0.3922
# Epoch 8/20
# 7/7 [==============================] - 1s 91ms/step - loss: 1.0363 - accuracy: 0.4356 - val_loss: 1.0541 - val_accuracy: 0.3529
# Epoch 9/20
# 7/7 [==============================] - 1s 90ms/step - loss: 1.0298 - accuracy: 0.4554 - val_loss: 1.0505 - val_accuracy: 0.3922
# Epoch 10/20
# 7/7 [==============================] - 1s 93ms/step - loss: 1.0291 - accuracy: 0.4356 - val_loss: 1.0466 - val_accuracy: 0.3922
# Epoch 11/20
# 7/7 [==============================] - 1s 105ms/step - loss: 1.0316 - accuracy: 0.4208 - val_loss: 1.0395 - val_accuracy: 0.4510
# Epoch 12/20
# 7/7 [==============================] - 1s 100ms/step - loss: 1.0189 - accuracy: 0.4356 - val_loss: 1.0327 - val_accuracy: 0.5490
# Epoch 13/20
# 7/7 [==============================] - 1s 100ms/step - loss: 1.0274 - accuracy: 0.4059 - val_loss: 1.0378 - val_accuracy: 0.4902
# Epoch 14/20
# 7/7 [==============================] - 1s 95ms/step - loss: 1.0194 - accuracy: 0.4406 - val_loss: 1.0277 - val_accuracy: 0.5686
# Epoch 15/20
# 7/7 [==============================] - 1s 94ms/step - loss: 1.0043 - accuracy: 0.4901 - val_loss: 1.0246 - val_accuracy: 0.4314
# Epoch 16/20
# 7/7 [==============================] - 1s 100ms/step - loss: 0.9946 - accuracy: 0.5050 - val_loss: 1.0234 - val_accuracy: 0.4118
# Epoch 17/20
# 7/7 [==============================] - 1s 104ms/step - loss: 1.0034 - accuracy: 0.4752 - val_loss: 1.0188 - val_accuracy: 0.5098
# Epoch 18/20
# 7/7 [==============================] - 1s 96ms/step - loss: 0.9824 - accuracy: 0.4950 - val_loss: 1.0031 - val_accuracy: 0.5490
# Epoch 19/20
# 7/7 [==============================] - 1s 90ms/step - loss: 0.9863 - accuracy: 0.4703 - val_loss: 0.9804 - val_accuracy: 0.5882
# Epoch 20/20
# 7/7 [==============================] - 1s 107ms/step - loss: 0.9683 - accuracy: 0.5693 - val_loss: 0.9738 - val_accuracy: 0.6667

# %% [markdown]
# ### (2) 학습 데이타 + 검증 데이타 + 테스트 데이타 분리하여 학습

# %%
import cnn_model  # 내가 만든 CNN 모델 import
import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# 입력과 출력 지정하기 
im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color) # (32, 32, 3)
nb_classes = 3 # 레이블 수

# 사진 데이터 읽어 들이기 
photos = np.load('image/photos.npz')
x = photos['x']
y = photos['y']

# X 속성 데이터를 1차원에서 3차원 배열로 변환 + 정규화하기 
x = x.reshape(-1, im_rows, im_cols, im_color)
x = x.astype('float32') / 255

# Y 레이블을 One-hot 형식으로 변환하기 
y = to_categorical(y.astype('int32'), nb_classes)

# 학습 전용과 테스트 전용으로 구분하기 
x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                    test_size=0.2,
                                                   random_state=777)
# 검증 데이타 만들기
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, 
                                                  test_size=0.2,
                                                  random_state=777)

# CNN 모델 만들기 
model = cnn_model.get_model(in_shape, nb_classes)

# 학습 실행하기 
hist = model.fit(x_train, y_train,
          batch_size=32,
          epochs=20,
          verbose=1,
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 6/6 [==============================] - 1s 94ms/step - loss: 1.0947 - accuracy: 0.3789 - val_loss: 1.0567 - val_accuracy: 0.4634
# Epoch 2/20
# 6/6 [==============================] - 0s 60ms/step - loss: 1.0519 - accuracy: 0.4845 - val_loss: 1.0506 - val_accuracy: 0.4878
# Epoch 3/20
# 6/6 [==============================] - 0s 57ms/step - loss: 1.0486 - accuracy: 0.4410 - val_loss: 1.0494 - val_accuracy: 0.4878
# Epoch 4/20
# 6/6 [==============================] - 0s 60ms/step - loss: 1.0383 - accuracy: 0.4596 - val_loss: 1.0480 - val_accuracy: 0.4878
# Epoch 5/20
# 6/6 [==============================] - 0s 64ms/step - loss: 1.0521 - accuracy: 0.4161 - val_loss: 1.0373 - val_accuracy: 0.4878
# Epoch 6/20
# 6/6 [==============================] - 0s 54ms/step - loss: 1.0412 - accuracy: 0.4472 - val_loss: 1.0331 - val_accuracy: 0.4878
# Epoch 7/20
# 6/6 [==============================] - 0s 49ms/step - loss: 1.0500 - accuracy: 0.3913 - val_loss: 1.0377 - val_accuracy: 0.5122
# Epoch 8/20
# 6/6 [==============================] - 0s 51ms/step - loss: 1.0446 - accuracy: 0.4658 - val_loss: 1.0409 - val_accuracy: 0.4634
# Epoch 9/20
# 6/6 [==============================] - 0s 51ms/step - loss: 1.0345 - accuracy: 0.3975 - val_loss: 1.0412 - val_accuracy: 0.4878
# Epoch 10/20
# 6/6 [==============================] - 0s 49ms/step - loss: 1.0296 - accuracy: 0.4658 - val_loss: 1.0427 - val_accuracy: 0.5122
# Epoch 11/20
# 6/6 [==============================] - 0s 52ms/step - loss: 1.0113 - accuracy: 0.4534 - val_loss: 1.0306 - val_accuracy: 0.4878
# Epoch 12/20
# 6/6 [==============================] - 0s 48ms/step - loss: 1.0267 - accuracy: 0.4161 - val_loss: 1.0155 - val_accuracy: 0.4878
# Epoch 13/20
# 6/6 [==============================] - 0s 48ms/step - loss: 1.0273 - accuracy: 0.4410 - val_loss: 1.0063 - val_accuracy: 0.4878
# Epoch 14/20
# 6/6 [==============================] - 0s 49ms/step - loss: 1.0395 - accuracy: 0.4099 - val_loss: 1.0020 - val_accuracy: 0.4878
# Epoch 15/20
# 6/6 [==============================] - 0s 52ms/step - loss: 1.0261 - accuracy: 0.4161 - val_loss: 1.0028 - val_accuracy: 0.5366
# Epoch 16/20
# 6/6 [==============================] - 0s 47ms/step - loss: 1.0155 - accuracy: 0.4472 - val_loss: 1.0051 - val_accuracy: 0.5610
# Epoch 17/20
# 6/6 [==============================] - 0s 48ms/step - loss: 1.0219 - accuracy: 0.4099 - val_loss: 1.0264 - val_accuracy: 0.4878
# Epoch 18/20
# 6/6 [==============================] - 0s 49ms/step - loss: 1.0054 - accuracy: 0.4845 - val_loss: 1.0445 - val_accuracy: 0.4634
# Epoch 19/20
# 6/6 [==============================] - 0s 52ms/step - loss: 1.0170 - accuracy: 0.4845 - val_loss: 1.0424 - val_accuracy: 0.4390
# Epoch 20/20
# 6/6 [==============================] - 0s 48ms/step - loss: 0.9879 - accuracy: 0.5217 - val_loss: 1.0241 - val_accuracy: 0.4878

# %%
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (161, 32, 32, 3) (161, 3)
# (41, 32, 32, 3) (41, 3)
# (51, 32, 32, 3) (51, 3)

# %%
# 모델 평가하기 
score = model.evaluate(x_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0241 - accuracy: 0.4878
# 정답률= 0.4878048896789551 loss= 1.0241241455078125

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# 학습 상태를 그래프로 그리기 
import matplotlib.pyplot as plt

his_dict = hist.history
loss = his_dict['loss']
val_loss = his_dict['val_loss'] 

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 훈련 및 검증 손실 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['accuracy']
val_acc = his_dict['val_accuracy']

# 훈련 및 검증 정확도 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()

plt.show()

# %% [markdown]
# ### 7) 학습 데이타의 수량 늘리기
# - 정답률을 높이기 위해서 데이타 수량을 늘려서 진행
# - 사진을 회전하거나 반전시켜서 데이타 수량을 늘리기

# %% [markdown]
# ### OpenCV를 사용하여 이미지를 ~ 180도까지 회전
# - pip install opencv-python

# %%
import matplotlib.pyplot as plt
import cv2

# 사진 데이터 읽어 들이기
photos = np.load('image/photos.npz')
x = photos['x']
img = x[20] # 사진 하나만 선택하기

plt.figure(figsize=(10,10))
for i in range(36):
    plt.subplot(6,6,i+1)
    # 회전 시키기 
    center = (16, 16) # 회전 중심
    angle = i * 5 # 각도 조정
    scale = 1.0   # 확대 비율
    mtx = cv2.getRotationMatrix2D(center, angle, scale)
    img2 = cv2.warpAffine(img, mtx, (32, 32))
    # 화면에 출력하기
    plt.imshow(img2)
plt.show()

# %% [markdown]
# ### 8) 이미지 데이타 수량 늘리고 학습하기

# %%
# CNN으로 MNIST 분류 문제 풀기
import cnn_model
import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import cv2

# 입력과 출력 지정하기
im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

# 사진 데이터 읽어 들이기
photos = np.load('image/photos.npz')
x = photos['x']
y = photos['y']

# X 속성 데이터를 3차원 배열로 변환, 정규화하기
x = x.reshape(-1, im_rows, im_cols, im_color)
x = x.astype('float32') / 255

# 레이블 데이터를 One-hot 형식으로 변환하기
y = to_categorical(y.astype('int32'), nb_classes)

# 학습 전용과 테스트 전용으로 구분하기
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size=0.2,
                                                   random_state=777)

# 검증 데이타 만들기
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, 
                                                  test_size=0.2,
                                                  random_state=777)

# 이미지 증식 - 학습 데이타만 적용(테스트 데이타 증식 X)
x_new = []
y_new = []
for i, xi in enumerate(x_train):
    yi = y_train[i]
    for ang in range(-30, 30, 5):
        # 회전 시키기 
        center = (16, 16) # 회전 중심
        mtx = cv2.getRotationMatrix2D(center, ang, 1.0)
        xi2 = cv2.warpAffine(xi, mtx, (32, 32))
        x_new.append(xi2)
        y_new.append(yi)
        # 좌우 반전 
        xi3 = cv2.flip(xi2, 1)
        x_new.append(xi3)
        y_new.append(yi)

# 이미지를 늘린 데이터를 학습 데이터로 사용하기
print('수량을 늘리기 전=', len(y_train))
x_train = np.array(x_new)
y_train = np.array(y_new)
print('수량을 늘린 후=', len(y_train))

# CNN 모델 만들기 
model = cnn_model.get_model(in_shape, nb_classes)

# 학습 실행하기 
hist = model.fit(x_train, y_train,
          batch_size=32,
          epochs=20,
          verbose=1,
          validation_data=(x_val, y_val))
# Out:
# 수량을 늘리기 전= 161
# 수량을 늘린 후= 3864
# Epoch 1/20
# 121/121 [==============================] - 7s 57ms/step - loss: 1.0422 - accuracy: 0.4400 - val_loss: 1.0244 - val_accuracy: 0.4878
# Epoch 2/20
# 121/121 [==============================] - 7s 56ms/step - loss: 0.8945 - accuracy: 0.5831 - val_loss: 0.9061 - val_accuracy: 0.5610
# Epoch 3/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.7246 - accuracy: 0.6863 - val_loss: 0.7983 - val_accuracy: 0.6098
# Epoch 4/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.6415 - accuracy: 0.7197 - val_loss: 0.8012 - val_accuracy: 0.5610
# Epoch 5/20
# 121/121 [==============================] - 7s 58ms/step - loss: 0.5633 - accuracy: 0.7474 - val_loss: 0.6416 - val_accuracy: 0.7317
# Epoch 6/20
# 121/121 [==============================] - 7s 56ms/step - loss: 0.5127 - accuracy: 0.7723 - val_loss: 0.7112 - val_accuracy: 0.6585
# Epoch 7/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.4471 - accuracy: 0.8137 - val_loss: 0.6518 - val_accuracy: 0.7317
# Epoch 8/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.3973 - accuracy: 0.8295 - val_loss: 0.7395 - val_accuracy: 0.7073
# Epoch 9/20
# 121/121 [==============================] - 7s 56ms/step - loss: 0.3423 - accuracy: 0.8600 - val_loss: 0.7937 - val_accuracy: 0.7073
# Epoch 10/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.2959 - accuracy: 0.8835 - val_loss: 0.8134 - val_accuracy: 0.7317
# Epoch 11/20
# 121/121 [==============================] - 7s 58ms/step - loss: 0.2502 - accuracy: 0.9045 - val_loss: 0.8757 - val_accuracy: 0.7073
# Epoch 12/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.2167 - accuracy: 0.9177 - val_loss: 0.8718 - val_accuracy: 0.7073
# Epoch 13/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.1902 - accuracy: 0.9319 - val_loss: 0.9249 - val_accuracy: 0.6585
# Epoch 14/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.1573 - accuracy: 0.9457 - val_loss: 0.9807 - val_accuracy: 0.7317
# Epoch 15/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.1449 - accuracy: 0.9477 - val_loss: 1.2703 - val_accuracy: 0.6829
# Epoch 16/20
# 121/121 [==============================] - 7s 58ms/step - loss: 0.1284 - accuracy: 0.9573 - val_loss: 1.0065 - val_accuracy: 0.7073
# Epoch 17/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.1098 - accuracy: 0.9653 - val_loss: 1.2190 - val_accuracy: 0.6098
# Epoch 18/20
# 121/121 [==============================] - 7s 57ms/step - loss: 0.0961 - accuracy: 0.9692 - val_loss: 1.2759 - val_accuracy: 0.6585
# Epoch 19/20
# 121/121 [==============================] - 7s 58ms/step - loss: 0.0836 - accuracy: 0.9780 - val_loss: 1.3768 - val_accuracy: 0.6585
# Epoch 20/20
# 121/121 [==============================] - 7s 58ms/step - loss: 0.0723 - accuracy: 0.9793 - val_loss: 1.4611 - val_accuracy: 0.6585

# %%
# 모델 평가하기 
score = model.evaluate(x_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4592 - accuracy: 0.7255
# 정답률= 0.7254902124404907 loss= 1.4591991901397705

# %% [markdown]
# ### 9) 학습 상태를 그래프로 그리기

# %%
# 학습 상태를 그래프로 그리기 
import matplotlib.pyplot as plt

his_dict = hist.history
loss = his_dict['loss']
val_loss = his_dict['val_loss'] 

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 학습 및 데트스 손실(loss) 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['accuracy']
val_acc = his_dict['val_accuracy']

# 학습 및 데이타 정확도(accuracy) 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()

plt.show()

# %% [markdown]
# ### 10) 학습결과 저장하기
# - CNN 모델 저장 => photos-cnn.h5
# - 학습된 데이타 저장 => photos-cnn-weight.h5

# %%
# 모델 저장
model.save('./photos-cnn-model.h5')

# %%
# 학습된 가중치 데이타 저장
model.save_weights('./photos-cnn-weight.hdf5')

# %% [markdown]
# ### 11) 직접 찍은 사진으로 테스트 하기
# - 칼로리표
# - 초밥 : 588 kcal
# - 샐러드 : 118 kcal
# - 마파두부 : 648 kcal

# %%
import os
os.getcwd()
# Out:
# 'D:\\한국경영인증원\\2021\\디지털핵심실무인재양성\\딥러닝\\소스코드\\딥러닝소스코드(수강생)\\CNN 프로젝트\\4. 요리이미지분류_CNN'

# %%
import cnn_model
import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# target_image = "test-sushi.jpg"

im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

LABELS = ["초밥", "샐러드", "마파두부"] # 레이블의 음식 이름
CALORIES = [588, 118, 648] # 각 레이블별 칼로리

# 저장한 CNN 모델 읽어 들이기
model = load_model('./photos-cnn-model.h5')
model.load_weights('./photos-cnn-weight.hdf5')

def check_photo(path):
    # 이미지 읽어 들이기
    img = Image.open(path)
    img = img.convert("RGB") # 색공간 변환하기
    img = img.resize((im_cols, im_rows)) # 크기 변경하기
    plt.imshow(img)
    plt.show()
    
    # 3차원으로 데이터 변환하기 + 정규화
    x = np.asarray(img)
    x = x.reshape(-1, im_rows, im_cols, im_color)
    x = x / 255

    # 예측하기
    pre = model.predict([x])[0]
#     print(pre)
    idx = pre.argmax()
    per = int(pre[idx] * 100)
    return (idx, per)

def check_photo_str(path):
    idx, per = check_photo(path)
    # 응답하기
    print("이 사진은", LABELS[idx], "\b로(으로), 칼로리는", CALORIES[idx],"kcal입니다.")
    print("정확도는", per, "%")

# 메인 프로그램
if __name__ == '__main__':
    check_photo_str('test-sushi2.jpg')
    check_photo_str('test-salad2.jpg')
# Out:
# 로(으로), 칼로리는 588 kcal입니다.
# 정확도는 99 %
# 로(으로), 칼로리는 118 kcal입니다.
# 정확도는 99 %

# %% [markdown]
# ### 12) 저장된 딥러닝 모델, 학습된 데이타 불러와서 예측하기
# - from keras.models import load_model
# -  CNN 모델 읽기
#     - model = load_model('food-cnn.h5')
# - 학습된 데이타 불러오기
#     - model.load_weights('food-cnn-weight.h5')

# %%
import cv2
import numpy as np
import tensorflow.keras
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

im_rows = 32
im_cols = 32
in_shape = (im_rows, im_cols, 3)

# 레이블 정보 - 10개 클래스
labels = ["초밥", "샐러드", "마파두부"]

# CNN 모델 읽기
model = load_model('photos-cnn-model.h5')
# 학습된 데이타 불러오기
model.load_weights('photos-cnn-weight.hdf5')

# OpenCV를 사용해서 이미지 읽어 들이기
im = cv2.imread('test-sushi.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
im = cv2.resize(im, (32, 32))
plt.imshow(im) # 이미지 출력하기
plt.show()

# 학습한 이미지 데이터에 형태 맞추기
im = im.reshape(in_shape).astype('float32') / 255

# 예측하기
r = model.predict(np.array([im]), batch_size=32,verbose=1)
res = r[0]

# 결과 출력하기
for i, acc in enumerate(res):
    print(labels[i], "=", round(float(acc * 100), 4))
    
print("---"*12)
idx = res.argmax()
per = float(round(res[idx] * 100, 4))
print("예측한 결과 = index :", idx, "\b,", str(round(per,4)) + "%")
# Out:
# 1/1 [==============================] - 0s 2ms/step
# 초밥 = 1.2933
# 샐러드 = 98.6941
# 마파두부 = 0.0126
# ------------------------------------
# 예측한 결과 = index : 1, 98.6941%

# %% [markdown]
# ### 13) 예측 결과를 html 파일로 저장하기 => "predict-result.html"

# %%
import cnn_model
import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from tensorflow.keras.models import load_model

# target_image = "test-sushi.jpg"

im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

LABELS = ["초밥", "샐러드", "마파두부"]
CALORIES = [588, 118, 648] # 각 레이블의 칼로리

# 저장한 CNN 모델 읽어 들이기
# model = cnn_model.get_model(in_shape, nb_classes)

# CNN 모델 읽기
model = load_model('photos-cnn-model.h5')
# 학습된 데이타 불러오기
model.load_weights('photos-cnn-weight.hdf5')
# M학습한 이미지 데이터에 형태 맞추기
# im = im.reshape(in_shape).astype('float32') / 255

def check_photo(path):
    # 이미지 읽어 들이기
    img = Image.open(path)
    img = img.convert("RGB") # 색공간 변환하기
    img = img.resize((im_cols, im_rows)) # 크기 변경하기
    plt.imshow(img)
    plt.show()
    
    # 데이터 변환하기
    x = np.asarray(img)
    x = x.reshape(-1, im_rows, im_cols, im_color)
    x = x / 255

    # 예측하기
    pre = model.predict([x])[0]
    idx = pre.argmax()
    per = round(float(pre[idx] * 100),3)
    return (idx, per)


result = [] # 여러개의 이미지 파일 예측결과를 리스트로 저장하기
def check_photo_str(path):
    idx, per = check_photo(path)
    # 응답하기
    print("이 사진은", LABELS[idx], "로(으로), 칼로리는", CALORIES[idx],"kcal입니다.")
    print("가능성은", per, "%")
  
    # HTML로 저장하기------------------------------
    # 딥러닝 예측 결과 
    srcfile = path
    html = ""
    html = """<html><head><meta charset="utf8"></head>
    <body><h3>원본 이미지</h3><p>
    <img src='{0}' width=400></p>{1}""".format(path, html)
    
    res = "이 사진은 " + LABELS[idx] + "로(으로), 칼로리는" + str(CALORIES[idx]) +"kcal입니다."
    res = res + "<p>예측 정확도는" + str(per) + "% 입니다.</p><br>"
       
    s = '<div style="float:center;"><p><h3>'+ "딥러닝 결과 "+'</p></h3><h3>' + res + '</h3>'+ '</div>'
    html += s
    end = "</body></html>"  
    html += end
    print('-'*100)
    print(html)
    print('-'*100)
    result.append(html)
    
    # html을 파일로 저장하기
    with open("./predict-result.html", "w", encoding="utf-8") as f:
        for item in result :
            f.writelines(item)
    print("ok")

if __name__ == '__main__':
    check_photo_str('test-sushi.jpg')
    check_photo_str('test-salad.jpg')
# Out:
# 이 사진은 초밥 로(으로), 칼로리는 588 kcal입니다.
# 가능성은 77.85 %
# ----------------------------------------------------------------------------------------------------
# <html><head><meta charset="utf8"></head>
#     <body><h3>원본 이미지</h3><p>
#     <img src='test-sushi.jpg' width=400></p><div style="float:center;"><p><h3>딥러닝 결과 </p></h3><h3>이 사진은 초밥로(으로), 칼로리는588kcal입니다.<p>예측 정확도는77.85% 입니다.</p><br></h3></div></body></html>
# ----------------------------------------------------------------------------------------------------
# ok
# 이 사진은 샐러드 로(으로), 칼로리는 118 kcal입니다.
# 가능성은 99.833 %
# ----------------------------------------------------------------------------------------------------
# <html><head><meta charset="utf8"></head>
#     <body><h3>원본 이미지</h3><p>
#     <img src='test-salad.jpg' width=400></p><div style="float:center;"><p><h3>딥러닝 결과 </p></h3><h3>이 사진은 샐러드로(으로), 칼로리는118kcal입니다.<p>예측 정확도는99.833% 입니다.</p><br></h3></div></body></html>
# ----------------------------------------------------------------------------------------------------
# ok
