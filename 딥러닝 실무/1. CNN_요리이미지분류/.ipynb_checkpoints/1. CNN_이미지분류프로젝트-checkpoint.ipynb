# %% [markdown]
# # CNN을 활용한 이미지 분류 프로젝트

# %% [markdown]
# ### 요리 이미지 판정 방법
# - 1) 사진에 어떤 요리가 있는지 분류 – 피자, 스파게티, 스시 3종류의 요리 학습
# - 2) 판정한 요리의 칼로리를 출력

# %% [markdown]
# ### 요리 이미지 데이터 수집
# - 피자, 스파게티, 스시 3가지 종류 요리 => 음식당 100장 이상의 사진 필요
# - Flickr 사이트 이용
#     - Flickr가 제공하는 사진검색 API를 사용하여 요리사진 수집
#     - 사이트 : https://www.flickr.com/

# %% [markdown]
# # CNN을 활용한 이미지 분류 프로젝트

# %% [markdown]
# ## 1. 데이타 준비 및 정리

# %% [markdown]
# ### 1) Flickr API를 사용해 사진 수집
# ### (1) Flickr API 계정 만들기
# - 구글 아이디로 계정 만들기
# - Flickr API 계정 만들기 https://www.flickr.com/services/api/
#
# ### Flickr API 모듈 설치하기
# - pip install flickrapi

# %%
# 경고(worning) 무시
import warnings
warnings.filterwarnings('ignore')

# %%
# 현재 작업 디렉토리 확인하기
import os
os.getcwd()
# Out:
# '/Users/jeseung/Documents/Computer_Learnig/딥러닝 실무/1. CNN_요리이미지분류'

# %% [markdown]
# ### (2) Flickr API를 이용하여 요리 이미지 내려 받기
# - 피자, 스파게티, 스시 3가지 요리당 75X75 픽셀의 정사각형 이미지를 300개씩 내려 받기
# - ./image/pizza, ./image/spaghetti, ./image/sushi 폴더 생성
# <img src="./img/이미지다운로드.jpg" width=600 align=left>

# %%
# Flickr로 사진 검색해서 다운로드하기
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys

# API 키 지정하기
key = "6d05bacfa5143672199cd80a67f9cc48"
secret = "507801379dbd3e99"
wait_time = 1 # 대기 시간(초)

# image 디렉토리가 존재하지 않은 경우에만 디렉토리 생성
if not os.path.exists('./image/'):
    os.mkdir('./image/')

# Flickr API로 사진 검색하고 './image' 아래에 요리 이름 폴더별로 저장하기
def go_download(keyword, dir):  # go_download('피자', 'pizza')     
    # 저장 경로 지정하기
    savedir = "./image/" + dir  # "./image/pizza"   
    
    # 디렉토리가 존재하지 않은 경우에만 디렉토리 생성    
    if not os.path.exists(savedir):
        os.mkdir(savedir)    
        
    # API를 사용해서 json 형태의 데이타 다운로드하기 
    flickr = FlickrAPI(key, secret, format='parsed-json')
    res = flickr.photos.search(
      text = keyword,     # 키워드
      per_page = 200,     # 검색할 개수
      media = 'photos',   # 사진 검색
      sort = "relevance", # 키워드 관련도 순서
      safe_search = 1,    # 안전 검색
      extras = 'url_q, license')
    
    # 결과 확인하기
    photos = res['photos']
    pprint(photos)
    
    try:
      # 1장씩 다운로드하기 
      for i, photo in enumerate(photos['photo']):
        url_q = photo['url_q']
        filepath = savedir + '/' + dir + '_' + str(i) + '.jpg'
        if os.path.exists(filepath): continue
        print(str(i+1) + ":download=", url_q)
        urlretrieve(url_q, filepath)
        time.sleep(wait_time)
    except:
        import traceback
        traceback.print_exc()
        
# 키워드와 디렉터리 이름 지정해서 다운로드하기 
def main():
#    go_download('피자', 'pizza')
     go_download('스파게티', 'spaghetti')
     go_download('스시', 'sushi')

# 메인 프로그램     
if __name__ == '__main__':
    main()
# Out:
# {'page': 1,
#  'pages': 4,
#  'perpage': 200,
#  'photo': [{'farm': 8,
#             'height_q': 150,
#             'id': '7209511582',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '69329210@N02',
#             'secret': '505e1a1796',
#             'server': '7074',
#             'title': '스파게티 버섯버전2',
#             'url_q': 'https://live.staticflickr.com/7074/7209511582_505e1a1796_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '7001287542',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '69329210@N02',
#             'secret': '8841101d25',
#             'server': '7068',
#             'title': '또다른 스파게티',
#             'url_q': 'https://live.staticflickr.com/7068/7001287542_8841101d25_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6894297397',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '69329210@N02',
#             'secret': 'ffa30eb9b8',
#             'server': '7049',
#             'title': '상당히 잘된 스파게티',
#             'url_q': 'https://live.staticflickr.com/7049/6894297397_ffa30eb9b8_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2755561634',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '85475411b0',
#             'server': '3150',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/3150/2755561634_85475411b0_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '4571428596',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '22036096@N02',
#             'secret': '6a3b76c847',
#             'server': '3435',
#             'title': '크림맛이 진했던 스파게티....',
#             'url_q': 'https://live.staticflickr.com/3435/4571428596_6a3b76c847_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '4610360955',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '43215966@N03',
#             'secret': '5bd990b6d7',
#             'server': '1384',
#             'title': '인도 커리 스파게티',
#             'url_q': 'https://live.staticflickr.com/1384/4610360955_5bd990b6d7_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '48728592666',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '158176988@N03',
#             'secret': '38c6eaeac2',
#             'server': '65535',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/65535/48728592666_38c6eaeac2_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '5743235882',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '67347235@N00',
#             'secret': '4e711ccd1e',
#             'server': '3642',
#             'title': '태국 라면',
#             'url_q': 'https://live.staticflickr.com/3642/5743235882_4e711ccd1e_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '7904274910',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50154521@N08',
#             'secret': '96de8afc5e',
#             'server': '8307',
#             'title': 'pasta',
#             'url_q': 'https://live.staticflickr.com/8307/7904274910_96de8afc5e_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3121374761',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': '8f43cd850f',
#             'server': '3293',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/3293/3121374761_8f43cd850f_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '9042077964',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '28021450@N05',
#             'secret': 'e48896718e',
#             'server': '7372',
#             'title': '아트나인 파스타',
#             'url_q': 'https://live.staticflickr.com/7372/9042077964_e48896718e_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3559471288',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28991751@N07',
#             'secret': '0bacb8fe19',
#             'server': '3608',
#             'title': 'R0010922',
#             'url_q': 'https://live.staticflickr.com/3608/3559471288_0bacb8fe19_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4389575884',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '1cd619332d',
#             'server': '4070',
#             'title': 'spaghetti',
#             'url_q': 'https://live.staticflickr.com/4070/4389575884_1cd619332d_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3684298794',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '32917190@N02',
#             'secret': '14ce3f454d',
#             'server': '3619',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/3619/3684298794_14ce3f454d_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '7904275082',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50154521@N08',
#             'secret': '819d187bdd',
#             'server': '8171',
#             'title': 'pasta',
#             'url_q': 'https://live.staticflickr.com/8171/7904275082_819d187bdd_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4180792782',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42777912@N03',
#             'secret': '967b991b9d',
#             'server': '2759',
#             'title': '스파게티~',
#             'url_q': 'https://live.staticflickr.com/2759/4180792782_967b991b9d_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6141813287',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '61593371@N06',
#             'secret': '97bffd1f52',
#             'server': '6083',
#             'title': '2011-09-12-015',
#             'url_q': 'https://live.staticflickr.com/6083/6141813287_97bffd1f52_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '1722837860',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '4',
#             'owner': '7828283@N04',
#             'secret': '03651ef92b',
#             'server': '2179',
#             'title': 'SG104383',
#             'url_q': 'https://live.staticflickr.com/2179/1722837860_03651ef92b_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '1722896782',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '4',
#             'owner': '7828283@N04',
#             'secret': 'a5cce92108',
#             'server': '2061',
#             'title': 'SG104380',
#             'url_q': 'https://live.staticflickr.com/2061/1722896782_a5cce92108_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2073326663',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '65522415@N00',
#             'secret': 'f7e5e01986',
#             'server': '2398',
#             'title': 'P1110042',
#             'url_q': 'https://live.staticflickr.com/2398/2073326663_f7e5e01986_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '26248479030',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '45718437@N02',
#             'secret': '8716298ca5',
#             'server': '1691',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/1691/26248479030_8716298ca5_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '5001020776',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': 'a23ec057b3',
#             'server': '4092',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/4092/5001020776_a23ec057b3_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6871033885',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '76633338@N08',
#             'secret': '2ab30a6706',
#             'server': '7209',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/7209/6871033885_2ab30a6706_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6141813765',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '61593371@N06',
#             'secret': '1091269d3c',
#             'server': '6080',
#             'title': '2011-09-12-019',
#             'url_q': 'https://live.staticflickr.com/6080/6141813765_1091269d3c_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4074967684',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '30641011@N06',
#             'secret': '1970fa55dd',
#             'server': '2481',
#             'title': '짝꿍님이랑 마실나왔음',
#             'url_q': 'https://live.staticflickr.com/2481/4074967684_1970fa55dd_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4462032676',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '47968635@N05',
#             'secret': '9350863597',
#             'server': '2686',
#             'title': '점심 스파게티. 모자라면 비..',
#             'url_q': 'https://live.staticflickr.com/2686/4462032676_9350863597_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '5945743419',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50154521@N08',
#             'secret': '8bb505a3c4',
#             'server': '6135',
#             'title': 'Food',
#             'url_q': 'https://live.staticflickr.com/6135/5945743419_8bb505a3c4_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '5945743507',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50154521@N08',
#             'secret': '30a0c8bff7',
#             'server': '6132',
#             'title': 'Food',
#             'url_q': 'https://live.staticflickr.com/6132/5945743507_30a0c8bff7_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8474154829',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '84564139@N08',
#             'secret': 'b47da0d96b',
#             'server': '8526',
#             'title': '까르보나라 스파게티',
#             'url_q': 'https://live.staticflickr.com/8526/8474154829_b47da0d96b_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2073326773',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '65522415@N00',
#             'secret': '3df20b7405',
#             'server': '2160',
#             'title': 'P1110048',
#             'url_q': 'https://live.staticflickr.com/2160/2073326773_3df20b7405_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4429094432',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '13894733@N06',
#             'secret': 'a0680c6c60',
#             'server': '4001',
#             'title': '골벵이 스파게티',
#             'url_q': 'https://live.staticflickr.com/4001/4429094432_a0680c6c60_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5282185360',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': '51d453fc94',
#             'server': '5208',
#             'title': '크림 스파게티',
#             'url_q': 'https://live.staticflickr.com/5208/5282185360_51d453fc94_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4214238761',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '646bb91a1f',
#             'server': '4002',
#             'title': '살모네 스파게티',
#             'url_q': 'https://live.staticflickr.com/4002/4214238761_646bb91a1f_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6940524101',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '8853564@N03',
#             'secret': '14c76c9e72',
#             'server': '7188',
#             'title': '두부와 닭가슴살을 넣은 스파게티.',
#             'url_q': 'https://live.staticflickr.com/7188/6940524101_14c76c9e72_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2748617775',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28682831@N03',
#             'secret': 'a73239cc0a',
#             'server': '3141',
#             'title': '홈메이드 스파게티',
#             'url_q': 'https://live.staticflickr.com/3141/2748617775_a73239cc0a_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '15375940033',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '48550737@N05',
#             'secret': '0669314939',
#             'server': '7530',
#             'title': '이탈리안의 진수 스파게티 : Spaghetti',
#             'url_q': 'https://live.staticflickr.com/7530/15375940033_0669314939_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8274862683',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '79422659@N02',
#             'secret': '9ed3fb546c',
#             'server': '8338',
#             'title': '스파게티 구이..?',
#             'url_q': 'https://live.staticflickr.com/8338/8274862683_9ed3fb546c_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '33004276105',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': 'd4fb99fc8a',
#             'server': '3707',
#             'title': '미트볼 스파게티 Meatball Spaghetti',
#             'url_q': 'https://live.staticflickr.com/3707/33004276105_d4fb99fc8a_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3674868328',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '8277124@N07',
#             'secret': '2c35bc6f47',
#             'server': '2660',
#             'title': 'Overlooking Fremont',
#             'url_q': 'https://live.staticflickr.com/2660/3674868328_2c35bc6f47_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4308172417',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '27363890@N03',
#             'secret': '02c04ba7d2',
#             'server': '4011',
#             'title': '리미니 마레 올리오 스파게티',
#             'url_q': 'https://live.staticflickr.com/4011/4308172417_02c04ba7d2_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '1371919834',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '15623232@N00',
#             'secret': 'af3b27e286',
#             'server': '1220',
#             'title': '스파게티 완성',
#             'url_q': 'https://live.staticflickr.com/1220/1371919834_af3b27e286_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4867785773',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '23135839@N00',
#             'secret': '82db8002ae',
#             'server': '4094',
#             'title': '배고프니깐 스파게티.',
#             'url_q': 'https://live.staticflickr.com/4094/4867785773_82db8002ae_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3928058005',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '24971766@N06',
#             'secret': '7e34116b58',
#             'server': '2629',
#             'title': '동생표 이탈리아풍 된장질',
#             'url_q': 'https://live.staticflickr.com/2629/3928058005_7e34116b58_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '8164397144',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29895909@N00',
#             'secret': 'e3c5438436',
#             'server': '7274',
#             'title': '와인 가격이 3천원?? 소주만하네??? 물 처럼 마시고',
#             'url_q': 'https://live.staticflickr.com/7274/8164397144_e3c5438436_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '12619054553',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '76772130@N05',
#             'secret': 'd681dafc93',
#             'server': '7397',
#             'title': '해산물 스파게티',
#             'url_q': 'https://live.staticflickr.com/7397/12619054553_d681dafc93_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5250968200',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50808371@N08',
#             'secret': 'fc46d3bde4',
#             'server': '5169',
#             'title': '스파게티 맛있다.',
#             'url_q': 'https://live.staticflickr.com/5169/5250968200_fc46d3bde4_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '26416183164',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '115821677@N03',
#             'secret': 'e572c91fb4',
#             'server': '7456',
#             'title': '#디자인 #그래픽 #텍스타일 #패션 #추상 #그래픽디자인 #파스타 #스파게티 #패턴 '
#                      '#monkeynmouse #fashion #graphic #design #textile '
#                      '#psychedelic #abstract #pasta #spaghetti',
#             'url_q': 'https://live.staticflickr.com/7456/26416183164_e572c91fb4_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '23866252603',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '78174323@N00',
#             'secret': '3da317babf',
#             'server': '1582',
#             'title': '카르보나라 스파게티',
#             'url_q': 'https://live.staticflickr.com/1582/23866252603_3da317babf_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4183439007',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '39134142@N06',
#             'secret': 'ea674b9d41',
#             'server': '2530',
#             'title': '아무거나 성의없이 썰어서 막..',
#             'url_q': 'https://live.staticflickr.com/2530/4183439007_ea674b9d41_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '28035085890',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '78174323@N00',
#             'secret': '5b7ac50d06',
#             'server': '7550',
#             'title': '카르보나라 스파게티',
#             'url_q': 'https://live.staticflickr.com/7550/28035085890_5b7ac50d06_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '22119348201',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '131933886@N03',
#             'secret': '63cbd408a4',
#             'server': '5656',
#             'title': '2015.10.12  #알리오올리오  #마늘 완전 졓아 ~  #파스타 #먹방 #먹스타그램 #스파게티',
#             'url_q': 'https://live.staticflickr.com/5656/22119348201_63cbd408a4_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4292663940',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '13894733@N06',
#             'secret': '25e5eb3281',
#             'server': '2724',
#             'title': '간만에 피자+스파게티...',
#             'url_q': 'https://live.staticflickr.com/2724/4292663940_25e5eb3281_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '5116964821',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '45273454@N02',
#             'secret': '906751138c',
#             'server': '4103',
#             'title': '치킨 소세지  스파게티',
#             'url_q': 'https://live.staticflickr.com/4103/5116964821_906751138c_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '32693551593',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87936699@N06',
#             'secret': '80aea1dc4d',
#             'server': '3884',
#             'title': 'Chili Prawn & Tomato Spaghetti',
#             'url_q': 'https://live.staticflickr.com/3884/32693551593_80aea1dc4d_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5464731558',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '31477982@N02',
#             'secret': '560d46d9cb',
#             'server': '5055',
#             'title': '난 오늘부터 스파게티 요리사..',
#             'url_q': 'https://live.staticflickr.com/5055/5464731558_560d46d9cb_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2976673982',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '5',
#             'owner': '61753687@N00',
#             'secret': 'c096955b4e',
#             'server': '3144',
#             'title': '이것이 조개 스파게티 봉골레',
#             'url_q': 'https://live.staticflickr.com/3144/2976673982_c096955b4e_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6061327790',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '41646743@N02',
#             'secret': '21b48e752a',
#             'server': '6185',
#             'title': '크림 먹물 스파게티 @ in urban',
#             'url_q': 'https://live.staticflickr.com/6185/6061327790_21b48e752a_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3460510442',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '34388891@N08',
#             'secret': '4e12363a1e',
#             'server': '3517',
#             'title': 'spagetti',
#             'url_q': 'https://live.staticflickr.com/3517/3460510442_4e12363a1e_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '10957993945',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '5',
#             'owner': '105466062@N04',
#             'secret': 'b87d659379',
#             'server': '7321',
#             'title': '스파게티, by Ethan Lee',
#             'url_q': 'https://live.staticflickr.com/7321/10957993945_b87d659379_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6060773257',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '41646743@N02',
#             'secret': '3e77a5f3e7',
#             'server': '6206',
#             'title': '모짜렐라 토마토 스파게티 @ in urban',
#             'url_q': 'https://live.staticflickr.com/6206/6060773257_3e77a5f3e7_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6781850692',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '67347235@N00',
#             'secret': '7916be863a',
#             'server': '7193',
#             'title': '피자헛 와우박스 - 2',
#             'url_q': 'https://live.staticflickr.com/7193/6781850692_7916be863a_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '9281139463',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '23344263@N07',
#             'secret': '92159a6775',
#             'server': '7335',
#             'title': '토마토소스 파스타',
#             'url_q': 'https://live.staticflickr.com/7335/9281139463_92159a6775_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '29815344354',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '143827742@N02',
#             'secret': 'e1013b54cb',
#             'server': '5795',
#             'title': '면이랑 친하지가 않지만 아주 가끔은 좋더라  #먹스타그램 #먹방샷#일상#맞팔#맛스타그램 #면스타그램 '
#                      '#스파게티 #좋아요👍 #맛이따 #짱#데일리#오오티디#저녁식사#instalikes #instadaily '
#                      '#instaselfie #instagood #like4like #yummy #tasty '
#                      '#delicious #spagettios #bestpic#dinner',
#             'url_q': 'https://live.staticflickr.com/5795/29815344354_e1013b54cb_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '49932618183',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '10490729@N02',
#             'secret': 'e58c958f8c',
#             'server': '65535',
#             'title': 'DSCF1143',
#             'url_q': 'https://live.staticflickr.com/65535/49932618183_e58c958f8c_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '32836578933',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87936699@N06',
#             'secret': '7489928ba7',
#             'server': '3945',
#             'title': 'Carbonara Spaghetti',
#             'url_q': 'https://live.staticflickr.com/3945/32836578933_7489928ba7_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4296597511',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37353815@N03',
#             'secret': '86a78ba1e5',
#             'server': '4044',
#             'title': '이어지는 이탈리안 야키소바!!!',
#             'url_q': 'https://live.staticflickr.com/4044/4296597511_86a78ba1e5_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2218097083',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '86675569@N00',
#             'secret': 'a0378eab5a',
#             'server': '2199',
#             'title': '부엌의 모습',
#             'url_q': 'https://live.staticflickr.com/2199/2218097083_a0378eab5a_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '11020158743',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '99823436@N07',
#             'secret': '7618823c7c',
#             'server': '3792',
#             'title': '가만에 조리해보안네 #스파게티',
#             'url_q': 'https://live.staticflickr.com/3792/11020158743_7618823c7c_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '23651548208',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87936699@N06',
#             'secret': 'e8051952b5',
#             'server': '4508',
#             'title': 'Oil Based Shrimp & Tomato Pasta',
#             'url_q': 'https://live.staticflickr.com/4508/23651548208_e8051952b5_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '32254574545',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '98403995@N08',
#             'secret': '6d3a3bb097',
#             'server': '702',
#             'title': 'South Korea - Seoul - Restaurant - Preparing Korean '
#                      'Style Sushi Roll (Gimbap) - 33',
#             'url_q': 'https://live.staticflickr.com/702/32254574545_6d3a3bb097_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '52221611136',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '10490729@N02',
#             'secret': '55c8ffcd46',
#             'server': '65535',
#             'title': 'DSC07241',
#             'url_q': 'https://live.staticflickr.com/65535/52221611136_55c8ffcd46_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '5960291346',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '25662104@N02',
#             'secret': '2981091c5d',
#             'server': '6125',
#             'title': '스파게티 소스병이 안열려… :Q',
#             'url_q': 'https://live.staticflickr.com/6125/5960291346_2981091c5d_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8638926325',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '66897160@N03',
#             'secret': 'ef3055de05',
#             'server': '8121',
#             'title': '블랙스미스 강남역2호점 at 서초동 1307번지 2층. 맛있네요. 예전연인코스는 스테이크+스파게티 '
#                      '였는데. 최근엔 가벼운 씬피자와 파스타가 대세! 전 피칸테올리오를 주문.당분간 낮엔 행사가. '
#                      '파스파,피자를 저렴하게 드실수 있어요. 피자는  FM 마르게리따와 고르곤졸라.',
#             'url_q': 'https://live.staticflickr.com/8121/8638926325_ef3055de05_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3401571198',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '36454070@N05',
#             'secret': '8714fe4217',
#             'server': '3657',
#             'title': '스파게티 Story part..',
#             'url_q': 'https://live.staticflickr.com/3657/3401571198_8714fe4217_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8638927079',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '66897160@N03',
#             'secret': '4674c0e3c0',
#             'server': '8106',
#             'title': '블랙스미스 강남역2호점 at 서초동 1307번지 2층. 맛있네요. 예전연인코스는 스테이크+스파게티 '
#                      '였는데. 최근엔 가벼운 씬피자와 파스타가 대세! 전 피칸테올리오를 주문.당분간 낮엔 행사가. '
#                      '파스파,피자를 저렴하게 드실수 있어요. 피자는  FM 마르게리따와 고르곤졸라.',
#             'url_q': 'https://live.staticflickr.com/8106/8638927079_4674c0e3c0_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3401618704',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '36454070@N05',
#             'secret': 'a4d2554068',
#             'server': '3449',
#             'title': '스파게티 Story Part..',
#             'url_q': 'https://live.staticflickr.com/3449/3401618704_a4d2554068_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5287639777',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '40475866@N03',
#             'secret': '8722d5969d',
#             'server': '5046',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/5046/5287639777_8722d5969d_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3112733825',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'a61310bdc3',
#             'server': '3277',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/3277/3112733825_a61310bdc3_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '4610922540',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '43215966@N03',
#             'secret': '7a0e19272e',
#             'server': '1407',
#             'title': '해산물 토마토 스파게티',
#             'url_q': 'https://live.staticflickr.com/1407/4610922540_7a0e19272e_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4031273931',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97502594@N00',
#             'secret': '4591f7646f',
#             'server': '2628',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/2628/4031273931_4591f7646f_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '26125445116',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '134332434@N07',
#             'secret': 'f50131de94',
#             'server': '1523',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/1523/26125445116_f50131de94_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5233001078',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '95206870@N00',
#             'secret': '0dd8811661',
#             'server': '5089',
#             'title': '아침 먹기',
#             'url_q': 'https://live.staticflickr.com/5089/5233001078_0dd8811661_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3675109324',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '8930053@N08',
#             'secret': 'e9abdc5e6f',
#             'server': '2461',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/2461/3675109324_e9abdc5e6f_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5233001394',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '95206870@N00',
#             'secret': 'da912ea25c',
#             'server': '5009',
#             'title': '아침 먹기',
#             'url_q': 'https://live.staticflickr.com/5009/5233001394_da912ea25c_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '5742341670',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '34072796@N04',
#             'secret': '91d12b3669',
#             'server': '2535',
#             'title': '스파게티!!',
#             'url_q': 'https://live.staticflickr.com/2535/5742341670_91d12b3669_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5233002378',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '95206870@N00',
#             'secret': '5ddcf02532',
#             'server': '5164',
#             'title': '아침 먹기',
#             'url_q': 'https://live.staticflickr.com/5164/5233002378_5ddcf02532_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '24262056',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '27056886@N00',
#             'secret': '2057ad45ec',
#             'server': '21',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/21/24262056_2057ad45ec_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4267865696',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '98f43f790a',
#             'server': '4010',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/4010/4267865696_98f43f790a_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4394883353',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '51332396@N00',
#             'secret': '125d581330',
#             'server': '4069',
#             'title': 'P1000338',
#             'url_q': 'https://live.staticflickr.com/4069/4394883353_125d581330_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3425494692',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'c497cb9809',
#             'server': '3617',
#             'title': '갈릭 크림 파스타',
#             'url_q': 'https://live.staticflickr.com/3617/3425494692_c497cb9809_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4395648724',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '51332396@N00',
#             'secret': 'eeb7c2801e',
#             'server': '4038',
#             'title': 'P1000336',
#             'url_q': 'https://live.staticflickr.com/4038/4395648724_eeb7c2801e_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4395649246',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '51332396@N00',
#             'secret': '4e7f72d641',
#             'server': '2798',
#             'title': 'P1000337',
#             'url_q': 'https://live.staticflickr.com/2798/4395649246_4e7f72d641_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4395648124',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '51332396@N00',
#             'secret': '616c77b727',
#             'server': '4054',
#             'title': 'P1000335',
#             'url_q': 'https://live.staticflickr.com/4054/4395648124_616c77b727_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3566273303',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '7828283@N04',
#             'secret': 'e0695d9509',
#             'server': '2443',
#             'title': '갈릭 파스타',
#             'url_q': 'https://live.staticflickr.com/2443/3566273303_e0695d9509_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '13259078184',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '119955585@N07',
#             'secret': 'e9e720122b',
#             'server': '2818',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/2818/13259078184_e9e720122b_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2456086611',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '14809413@N00',
#             'secret': 'bff00c41d8',
#             'server': '2264',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/2264/2456086611_bff00c41d8_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5689464771',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '43ed043d96',
#             'server': '5310',
#             'title': '스파게티~',
#             'url_q': 'https://live.staticflickr.com/5310/5689464771_43ed043d96_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2492736781',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '70598351@N00',
#             'secret': '7a905bfb2f',
#             'server': '2310',
#             'title': '스파게티',
#             'url_q': 'https://live.staticflickr.com/2310/2492736781_7a905bfb2f_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6141815441',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '61593371@N06',
#             'secret': 'ff10902d88',
#             'server': '6067',
#             'title': '2011-09-12-047-광안리',
#             'url_q': 'https://live.staticflickr.com/6067/6141815441_ff10902d88_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4646220291',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '26433882@N02',
#             'secret': 'c9b326c778',
#             'server': '4030',
#             'title': '오늘의 식사는',
#             'url_q': 'https://live.staticflickr.com/4030/4646220291_c9b326c778_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4449207275',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '32917190@N02',
#             'secret': 'bb35c64c7c',
#             'server': '4042',
#             'title': '모짜레라 + 토마토',
#             'url_q': 'https://live.staticflickr.com/4042/4449207275_bb35c64c7c_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6141815131',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '61593371@N06',
#             'secret': '21ed309f53',
#             'server': '6193',
#             'title': '2011-09-12-031',
#             'url_q': 'https://live.staticflickr.com/6193/6141815131_21ed309f53_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4395654258',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '51332396@N00',
#             'secret': 'b2ce6f022c',
#             'server': '4005',
#             'title': 'P1000345',
#             'url_q': 'https://live.staticflickr.com/4005/4395654258_b2ce6f022c_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6142367056',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '61593371@N06',
#             'secret': '090e429c26',
#             'server': '6198',
#             'title': '2011-09-12-026',
#             'url_q': 'https://live.staticflickr.com/6198/6142367056_090e429c26_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4395652954',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '51332396@N00',
#             'secret': '06caeecb63',
#             'server': '4044',
#             'title': 'P1000342',
#             'url_q': 'https://live.staticflickr.com/4044/4395652954_06caeecb63_q.jpg',
# ...
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5724674224',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '53083846@N03',
#             'secret': '5f62a233fa',
#             'server': '5165',
#             'title': '스시 @ Yanagi Sushi',
#             'url_q': 'https://live.staticflickr.com/5165/5724674224_5f62a233fa_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4432085675',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '14074262@N04',
#             'secret': '7383341265',
#             'server': '2719',
#             'title': '우메가 스시 미도리',
#             'url_q': 'https://live.staticflickr.com/2719/4432085675_7383341265_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6572411165',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42858813@N03',
#             'secret': 'ff99f8af37',
#             'server': '7013',
#             'title': '스시 먹는 작은 아가씨~~~..',
#             'url_q': 'https://live.staticflickr.com/7013/6572411165_ff99f8af37_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2993629659',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '57409478@N00',
#             'secret': 'd88fd47c61',
#             'server': '3001',
#             'title': '스시 스시 스시 :)',
#             'url_q': 'https://live.staticflickr.com/3001/2993629659_d88fd47c61_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35405190803',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87936699@N06',
#             'secret': '0cf940e300',
#             'server': '4303',
#             'title': 'California Roll',
#             'url_q': 'https://live.staticflickr.com/4303/35405190803_0cf940e300_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4416344848',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '48600099802@N01',
#             'secret': '830a1e18af',
#             'server': '2693',
#             'title': '수영 후의 스시. 먹고싶었다..',
#             'url_q': 'https://live.staticflickr.com/2693/4416344848_830a1e18af_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '26220871702',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '125576073@N05',
#             'secret': '5dbf5c840b',
#             'server': '1536',
#             'title': 'Sushiamo? 플레이스 #sushi #맞팔 #맛스타그램 #bushi #롤 #japanesefood '
#                      '#소통 #부쉬 #맛 #맛스타 #repost #스시리또 #트렌디 #sushi #회덥밥 #브리또 '
#                      '#연어온파이어 #스시 #bigò #역삼 #음식 #퓨전 #friday',
#             'url_q': 'https://live.staticflickr.com/1536/26220871702_5dbf5c840b_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3952278269',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42261220@N02',
#             'secret': '59518a2b43',
#             'server': '2566',
#             'title': '이거슨 스시부페왔으니까 스시..',
#             'url_q': 'https://live.staticflickr.com/2566/3952278269_59518a2b43_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4432084965',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '14074262@N04',
#             'secret': '844428d896',
#             'server': '2678',
#             'title': '우메가 스시 미도리',
#             'url_q': 'https://live.staticflickr.com/2678/4432084965_844428d896_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '25028088462',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37318982@N07',
#             'secret': '73c91b73d8',
#             'server': '1648',
#             'title': '구레 스시 진짜 올만에 오니까 대박 not omakaze but traditional japanese '
#                      'style courses - kaiseki 오 셰프 아저씨 잘먹었습니다~~~ #먹스타그램 '
#                      '#kaiseki #happyfood #daily',
#             'url_q': 'https://live.staticflickr.com/1648/25028088462_73c91b73d8_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2685240238',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '74119595@N00',
#             'secret': '6f1c401ac6',
#             'server': '3167',
#             'title': '오늘 저녁은 스시',
#             'url_q': 'https://live.staticflickr.com/3167/2685240238_6f1c401ac6_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '12534703793',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '10490729@N02',
#             'secret': '0ed8667bb7',
#             'server': '7405',
#             'title': 'あなご棒ずし - SDIM0320',
#             'url_q': 'https://live.staticflickr.com/7405/12534703793_0ed8667bb7_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4432857284',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '14074262@N04',
#             'secret': 'a14d2ee496',
#             'server': '4047',
#             'title': '우메가 스시 미도리',
#             'url_q': 'https://live.staticflickr.com/4047/4432857284_a14d2ee496_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '24608114986',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '130026328@N03',
#             'secret': '68303f9598',
#             'server': '1594',
#             'title': '#me & my #wifey #eating #sushi in #berlin #luisaandsong '
#                      '#freshfood #instafood #instagood #먹스타그램 #스시 #인스타푸드',
#             'url_q': 'https://live.staticflickr.com/1594/24608114986_68303f9598_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3545137811',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '32917190@N02',
#             'secret': 'b3294fd735',
#             'server': '2424',
#             'title': '저녁엔 스시 2',
#             'url_q': 'https://live.staticflickr.com/2424/3545137811_b3294fd735_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5660233106',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '61937047@N05',
#             'secret': '576bb7f639',
#             'server': '5023',
#             'title': '스시 좋아하는 알버트',
#             'url_q': 'https://live.staticflickr.com/5023/5660233106_576bb7f639_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '20254785525',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '133254193@N06',
#             'secret': 'f30c8efe6a',
#             'server': '272',
#             'title': '#스시 #연어 #번개',
#             'url_q': 'https://live.staticflickr.com/272/20254785525_f30c8efe6a_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4432089475',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '14074262@N04',
#             'secret': 'a8e1ca14d2',
#             'server': '4035',
#             'title': '우메가오카 스시 미도리',
#             'url_q': 'https://live.staticflickr.com/4035/4432089475_a8e1ca14d2_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '11380773715',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '48600099802@N01',
#             'secret': 'd44fdb6edd',
#             'server': '7424',
#             'title': "yuna's me2photo, Aug 29, 2011",
#             'url_q': 'https://live.staticflickr.com/7424/11380773715_d44fdb6edd_q.jpg',
#             'width_q': 150}],
#  'total': 619}
# 1:download= https://live.staticflickr.com/4064/4362282117_db551ecabf_q.jpg
# 2:download= https://live.staticflickr.com/5803/22707816333_c7d4341133_q.jpg
# 3:download= https://live.staticflickr.com/4054/4613588369_f20587cdc7_q.jpg
# 4:download= https://live.staticflickr.com/610/23226644912_ff2544b0db_q.jpg
# 5:download= https://live.staticflickr.com/3089/2520058940_5f4d2bdd31_q.jpg
# 6:download= https://live.staticflickr.com/3713/12046009365_692b6624eb_q.jpg
# 9:download= https://live.staticflickr.com/2734/4332817170_245fb0a1a0_q.jpg
# 11:download= https://live.staticflickr.com/8075/8260002382_64ede31d22_q.jpg
# 13:download= https://live.staticflickr.com/4121/4914650194_f8d2874b08_q.jpg
# 14:download= https://live.staticflickr.com/4323/35159195444_17e30a35b0_q.jpg
# 15:download= https://live.staticflickr.com/7288/8737578731_9c7874e30d_q.jpg
# 16:download= https://live.staticflickr.com/4299/35828039922_a883bfc176_q.jpg
# 17:download= https://live.staticflickr.com/3445/3844857716_a614854b96_q.jpg
# 18:download= https://live.staticflickr.com/1668/26122031213_5da979446b_q.jpg
# 21:download= https://live.staticflickr.com/5203/5349042376_ea99eccd2c_q.jpg
# 22:download= https://live.staticflickr.com/8661/29538567573_fd79f0f57c_q.jpg
# 24:download= https://live.staticflickr.com/1933/43810646640_15460cdc9a_q.jpg
# 25:download= https://live.staticflickr.com/3872/14280123438_839aa45b73_q.jpg
# 27:download= https://live.staticflickr.com/4031/4432088823_f17950b2c8_q.jpg
# 32:download= https://live.staticflickr.com/1810/28222280517_834a8c9280_q.jpg
# 39:download= https://live.staticflickr.com/3742/12924650053_a0e2ca1646_q.jpg
# 40:download= https://live.staticflickr.com/1667/25895030360_f237314752_q.jpg
# 41:download= https://live.staticflickr.com/3211/2962895073_df0588438c_q.jpg
# 42:download= https://live.staticflickr.com/5690/22034596215_57b3aae032_q.jpg
# 45:download= https://live.staticflickr.com/7362/12602460954_a80f7f1c05_q.jpg
# 47:download= https://live.staticflickr.com/5615/30673518972_5caced67dd_q.jpg
# 54:download= https://live.staticflickr.com/5577/30489345720_550bf2338e_q.jpg
# 55:download= https://live.staticflickr.com/3759/11147030993_fc5050b3a7_q.jpg
# 56:download= https://live.staticflickr.com/65535/51135326228_f7f66fae28_q.jpg
# 57:download= https://live.staticflickr.com/707/23334959815_5b75a361fa_q.jpg
# 59:download= https://live.staticflickr.com/691/23226644172_61387ae009_q.jpg
# 62:download= https://live.staticflickr.com/5722/23252388091_2cc79809cf_q.jpg
# 63:download= https://live.staticflickr.com/782/23226643962_eab85be54c_q.jpg
# 64:download= https://live.staticflickr.com/667/22967031779_bcf90a9c7a_q.jpg
# 65:download= https://live.staticflickr.com/5674/23039174230_e66e1039ec_q.jpg
# 66:download= https://live.staticflickr.com/4071/4485897969_70ea22cb94_q.jpg
# 69:download= https://live.staticflickr.com/3705/12046843746_9b1342bf81_q.jpg
# 70:download= https://live.staticflickr.com/3304/3413917783_f272f490cb_q.jpg
# 74:download= https://live.staticflickr.com/4519/38513131402_03af6e012a_q.jpg
# 75:download= https://live.staticflickr.com/2194/2519237785_da33b5ec91_q.jpg
# 76:download= https://live.staticflickr.com/2308/2384023607_8289b9e51b_q.jpg
# 77:download= https://live.staticflickr.com/157/364317862_7168bc5e1f_q.jpg
# 78:download= https://live.staticflickr.com/2297/2123838912_218c6bfa54_q.jpg
# 80:download= https://live.staticflickr.com/3211/3027691038_eb80a3f1c8_q.jpg
# 81:download= https://live.staticflickr.com/6152/6174382207_22678f4664_q.jpg
# 82:download= https://live.staticflickr.com/3541/3414740364_7b0517f43b_q.jpg
# 94:download= https://live.staticflickr.com/3373/3414734662_78ae70df42_q.jpg
# 95:download= https://live.staticflickr.com/3632/3413918637_80bded5c96_q.jpg
# 113:download= https://live.staticflickr.com/3427/3203272532_7de7beaf14_q.jpg
# 117:download= https://live.staticflickr.com/135/337293296_3b3e2ff9d3_q.jpg
# 122:download= https://live.staticflickr.com/6077/6092627662_e9107eded9_q.jpg
# 123:download= https://live.staticflickr.com/3461/3909227201_96d1d88521_q.jpg
# 124:download= https://live.staticflickr.com/7402/8718907493_efb142b4ea_q.jpg
# 126:download= https://live.staticflickr.com/6237/6337110364_ddfbc4993d_q.jpg
# 127:download= https://live.staticflickr.com/4309/35610026690_d0e59863a4_q.jpg
# 128:download= https://live.staticflickr.com/7282/8737577313_6206014961_q.jpg
# 129:download= https://live.staticflickr.com/7287/8738694864_8fe1e4b534_q.jpg
# 131:download= https://live.staticflickr.com/7286/8737575621_4d5b6d487f_q.jpg
# 132:download= https://live.staticflickr.com/2373/2123063857_7501c0ff26_q.jpg
# 135:download= https://live.staticflickr.com/5329/9802726066_c691ece634_q.jpg
# 139:download= https://live.staticflickr.com/2808/11616776034_2c837cf13d_q.jpg
# 140:download= https://live.staticflickr.com/5101/5660235038_50c0a738a4_q.jpg
# 141:download= https://live.staticflickr.com/3293/3129025172_985ca33315_q.jpg
# 151:download= https://live.staticflickr.com/7053/6955527353_1300dca14a_q.jpg
# 152:download= https://live.staticflickr.com/679/20835848973_e8c77687db_q.jpg
# 161:download= https://live.staticflickr.com/2886/9802715274_dc485fd6cd_q.jpg
# 162:download= https://live.staticflickr.com/577/22045312262_4eff47167d_q.jpg
# 163:download= https://live.staticflickr.com/8538/8691926338_3dbc928ba5_q.jpg
# 165:download= https://live.staticflickr.com/1708/24445908970_47b9c97ba9_q.jpg
# 166:download= https://live.staticflickr.com/2813/12300758393_741959abc0_q.jpg
# 167:download= https://live.staticflickr.com/2816/12558028174_bb786d972b_q.jpg
# 168:download= https://live.staticflickr.com/3508/3787175940_d50be30d28_q.jpg
# 170:download= https://live.staticflickr.com/7678/27619727605_31cccf7683_q.jpg
# 173:download= https://live.staticflickr.com/2902/13924760857_bbe69c997f_q.jpg
# 176:download= https://live.staticflickr.com/2831/12896659263_3cccf6ab91_q.jpg
# 180:download= https://live.staticflickr.com/7691/26611024313_73ea33aff8_q.jpg
# 181:download= https://live.staticflickr.com/2721/4432087135_a40aaed5c2_q.jpg
# 182:download= https://live.staticflickr.com/5165/5724674224_5f62a233fa_q.jpg
# 183:download= https://live.staticflickr.com/2719/4432085675_7383341265_q.jpg
# 187:download= https://live.staticflickr.com/2693/4416344848_830a1e18af_q.jpg
# 188:download= https://live.staticflickr.com/1536/26220871702_5dbf5c840b_q.jpg
# 190:download= https://live.staticflickr.com/2678/4432084965_844428d896_q.jpg
# 191:download= https://live.staticflickr.com/1648/25028088462_73c91b73d8_q.jpg
# 192:download= https://live.staticflickr.com/3167/2685240238_6f1c401ac6_q.jpg
# 194:download= https://live.staticflickr.com/4047/4432857284_a14d2ee496_q.jpg
# 195:download= https://live.staticflickr.com/1594/24608114986_68303f9598_q.jpg
# 196:download= https://live.staticflickr.com/2424/3545137811_b3294fd735_q.jpg
# 197:download= https://live.staticflickr.com/5023/5660233106_576bb7f639_q.jpg
# 200:download= https://live.staticflickr.com/7424/11380773715_d44fdb6edd_q.jpg

# %% [markdown]
# ### (3) 사진 정리하기(클린징)
# - 제대로 된 사진 100개만 남기기
# - 대상이 크게 나오고 다른 물체가 안나오고 색이 선명한 것 위주로 선택
# - 필터를 심하게 적용해 색상이 이상하거나 흑백 이미지는 제거

# %%
# 디렉토리 안의 이미지 파일 수 확인하기
import os, glob

path1 = "./image/pizza/"
path2 = "./image/spaghetti/"
path3 = "./image/sushi/"

# for img in glob.glob(path1 + "/*.jpg"):
#     print(img)
               
print("pizza: ", len(glob.glob(path1 + "/*.jpg")))
print("spaghetti: ", len(glob.glob(path2 + "/*.jpg")))
print("sushi: ", len(glob.glob(path3 + "/*.jpg")))
# Out:
# pizza:  126
# spaghetti:  156
# sushi:  163

# %% [markdown]
# ### 2) Numpy 형식으로 이미지 데이타 저장하기
# - 요리 사진을 데이터 셋으로 활용할 수 있게 Numpy 형식으로 변환하여 파일로 저장
#
# #### 작업 순서
# - 1) 요리 이미지가 컬러 이미지이므로 RGB 컬러로 변환
# - 2) RBG의 각 색상 값을 0~1까지의 실수로 변환
# - 3) 레이블 설정 - 0 : 피자, 1 : 스파게티, 2 : 스시
# - 4) image 디렉토리에 “photos.npz” 라는 Numpy 형식의 파일로 저장

# %%
# 이미지들을 NumPy 형식으로 변환하기
import numpy as np
from PIL import Image
import os, glob, random

outfile = "image/photos.npz" # 저장할 파일 이름
max_photo = 100 # 사용할 이미지 수
photo_size = 32 # 이미지 크기
x = [] # 이미지 데이터
y = [] # 레이블 데이터

def main():    
    # 디렉터리 읽어 들이기 
    glob_files("./image/pizza", 0)     # 레이블 설정 - glob_files("폴더명", 레이블)
    glob_files("./image/spaghetti", 1)
    glob_files("./image/sushi", 2)
    
    # 파일로 저장하기 
    np.savez(outfile, x=x, y=y)  # Numpy 압축파일로 저장
    print(str(len(x)) + "개의 이미지를", "저장했습니다. 파일명 :" + outfile)

# path 내부의 이미지 읽어 들이기 
def glob_files(path, label):        # glob_files("./image/pizza", 0)
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    
    # 파일 처리하기
    num = 0
    for f in files:
        if num >= max_photo: break
        num += 1
        # 이미지 파일 읽어 들이기
        img = Image.open(f)
        img = img.convert("RGB") # RGB 컬러로 변환하기
        img = img.resize((photo_size, photo_size)) # 크기 변경하기 - 32X32
        img = np.asarray(img) # RBG의 각 색상 값을 0~1까지의 실수로 변환
        x.append(img)
        y.append(label)
        
# 메인 프로그램     
if __name__ == '__main__':
    main()
# Out:
# 300개의 이미지를 저장했습니다. 파일명 :image/photos.npz

# %% [markdown]
# #### Numpy로 저장된 이미지 확인하기

# %%
import matplotlib.pyplot as plt
import numpy as np

# 사진 데이타 읽어 들이기
photos = np.load("image/photos.npz")
x = photos["x"]
y = photos["y"]

# 시작 인덱스 
idx = 0  # 100 or 200으로 변경하여 다른 이미지도 확인하기

# pyplot으로 출력하기
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])
    
plt.show()

# %%
# 시작 인덱스
idx = 100  # 100 or 200으로 변경하여 다른 이미지도 확인하기

# pyplot으로 출력하기
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])
    
plt.show()

# %%
# 시작 인덱스
idx = 200  # 100 or 200으로 변경하여 다른 이미지도 확인하기

# pyplot으로 출력하기
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])
    
plt.show()

# %% [markdown]
# ### 3) 데이타 전처리
# - 속성(피처) 데이터 - 1차원에서 3차원 배열로 변환, 정규화
# - 레이블 - 원-핫 인코딩 형식으로 변환

# %%
import tensorflow.keras
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# 입력 데이타와 출력 데이타 지정
im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간(RGB)
in_shape = (im_rows, im_cols, im_color) # (32, 32, 3) # 입력 데이타
nb_classes = 3 # 출력 데이타 수, 3종류의 요리

# 사진 데이터 읽어 들이기 
photos = np.load('image/photos.npz')
X = photos['x']
y = photos['y']

# x 속성(피처) 데이터를 1차원에서 3차원 배열로 변환 및 정규화하기 
X = x.reshape(-1, im_rows, im_cols, im_color)
X = x.astype('float32') / 255

# y 레이블을 원-핫 인코딩 형식으로 변환하기 
y = to_categorical(y.astype('int32'), nb_classes) # nb_classes=3

# %% [markdown]
# ### 4) 데이타 구분
# - 학습데이타셋, 검증데이타셋, 테스트데이타셋으로 구분

# %%
# 전체 데이타셋을 학습 데이타셋과 테스트셋으로 구분하기 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=0)

# 학습데이타셋을 학습데이셋과 검증데이타셋으로 구분하기
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2,
                                                  random_state=0)
# 데이타셋 형태 확인
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (192, 32, 32, 3) (192, 3)
# (48, 32, 32, 3) (48, 3)
# (60, 32, 32, 3) (60, 3)

# %% [markdown]
# ## 2. CNN 모델 정의, 컴파일 설정
# - cnn_model.py 파일로 저장

# %%
# cnn_model.py 파일 코드
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam

# CNN 모델 정의하기
def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', 
                     input_shape=in_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
    return model

# 컴파일하고 모델 반환하기
def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss='categorical_crossentropy',
        optimizer = Adam(1e-4),
        metrics=['acc'])
    return model

# %% [markdown]
# ## 3. CNN 모델 학습
# - 주피터에서 [Kernel --> Restart] 클릭하여 커널을 재시작한 후 실행
# - 정답률이 너무 안좋은 경우는 이미지 클리닝을 한 후 다시 실행하기

# %% [markdown]
# ### 1) ModelCheckpoint, Early_stopping  지정

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os

# 딥러닝 모델을 저장할 디렉토리(폴더) 생성
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./model/CNN_Cooking.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# ### 2) 모델 학습

# %%
import cnn_model  # 내가 만든 CNN 모델 import 하기

im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color) # (32, 32, 3) # 입력 데이타
nb_classes = 3 # 출력 데이타 수, 3종류의 요리

# CNN 모델 만들기 
model = cnn_model.get_model(in_shape, nb_classes)

# 모델 학습
history = model.fit(X_train, y_train,
          batch_size=32,
          epochs=30,
          verbose=1,
          validation_data=(X_val, y_val),
          callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 1/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.1058 - acc: 0.2438
# Epoch 1: val_loss improved from inf to 1.10462, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 1s 104ms/step - loss: 1.1023 - acc: 0.2552 - val_loss: 1.1046 - val_acc: 0.2708
# Epoch 2/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0919 - acc: 0.3625
# Epoch 2: val_loss did not improve from 1.10462
# 6/6 [==============================] - 0s 50ms/step - loss: 1.0947 - acc: 0.3490 - val_loss: 1.1057 - val_acc: 0.2500
# Epoch 3/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0939 - acc: 0.3625
# Epoch 3: val_loss did not improve from 1.10462
# 6/6 [==============================] - 0s 49ms/step - loss: 1.0938 - acc: 0.3646 - val_loss: 1.1048 - val_acc: 0.2708
# Epoch 4/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.1048 - acc: 0.3063
# Epoch 4: val_loss improved from 1.10462 to 1.10234, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 59ms/step - loss: 1.1020 - acc: 0.3333 - val_loss: 1.1023 - val_acc: 0.3542
# Epoch 5/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0983 - acc: 0.3063
# Epoch 5: val_loss improved from 1.10234 to 1.10088, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 58ms/step - loss: 1.0951 - acc: 0.3229 - val_loss: 1.1009 - val_acc: 0.3542
# Epoch 6/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0978 - acc: 0.3750
# Epoch 6: val_loss did not improve from 1.10088
# 6/6 [==============================] - 0s 48ms/step - loss: 1.0931 - acc: 0.3906 - val_loss: 1.1014 - val_acc: 0.2917
# Epoch 7/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0861 - acc: 0.4250
# Epoch 7: val_loss did not improve from 1.10088
# 6/6 [==============================] - 0s 48ms/step - loss: 1.0864 - acc: 0.4167 - val_loss: 1.1019 - val_acc: 0.2917
# Epoch 8/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0874 - acc: 0.3562
# Epoch 8: val_loss did not improve from 1.10088
# 6/6 [==============================] - 0s 50ms/step - loss: 1.0876 - acc: 0.3698 - val_loss: 1.1011 - val_acc: 0.2917
# Epoch 9/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0908 - acc: 0.3750
# Epoch 9: val_loss did not improve from 1.10088
# 6/6 [==============================] - 0s 50ms/step - loss: 1.0940 - acc: 0.3542 - val_loss: 1.1010 - val_acc: 0.2917
# Epoch 10/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0981 - acc: 0.3875
# Epoch 10: val_loss did not improve from 1.10088
# 6/6 [==============================] - 0s 50ms/step - loss: 1.0981 - acc: 0.3906 - val_loss: 1.1019 - val_acc: 0.3125
# Epoch 11/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0825 - acc: 0.3562
# Epoch 11: val_loss improved from 1.10088 to 1.10023, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 61ms/step - loss: 1.0855 - acc: 0.3646 - val_loss: 1.1002 - val_acc: 0.3125
# Epoch 12/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0846 - acc: 0.4125
# Epoch 12: val_loss improved from 1.10023 to 1.09729, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 60ms/step - loss: 1.0836 - acc: 0.4010 - val_loss: 1.0973 - val_acc: 0.2708
# Epoch 13/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0813 - acc: 0.4062
# Epoch 13: val_loss did not improve from 1.09729
# 6/6 [==============================] - 0s 50ms/step - loss: 1.0845 - acc: 0.3854 - val_loss: 1.0987 - val_acc: 0.3125
# Epoch 14/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0903 - acc: 0.3750
# Epoch 14: val_loss improved from 1.09729 to 1.09703, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 60ms/step - loss: 1.0852 - acc: 0.4010 - val_loss: 1.0970 - val_acc: 0.2917
# Epoch 15/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0795 - acc: 0.4000
# Epoch 15: val_loss did not improve from 1.09703
# 6/6 [==============================] - 0s 49ms/step - loss: 1.0787 - acc: 0.4062 - val_loss: 1.0979 - val_acc: 0.3125
# Epoch 16/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0810 - acc: 0.4062
# Epoch 16: val_loss improved from 1.09703 to 1.09379, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 60ms/step - loss: 1.0765 - acc: 0.4271 - val_loss: 1.0938 - val_acc: 0.3542
# Epoch 17/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0671 - acc: 0.4938
# Epoch 17: val_loss improved from 1.09379 to 1.09286, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 59ms/step - loss: 1.0652 - acc: 0.4896 - val_loss: 1.0929 - val_acc: 0.3542
# Epoch 18/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0492 - acc: 0.5437
# Epoch 18: val_loss did not improve from 1.09286
# 6/6 [==============================] - 0s 48ms/step - loss: 1.0596 - acc: 0.5260 - val_loss: 1.0966 - val_acc: 0.3125
# Epoch 19/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0566 - acc: 0.4750
# Epoch 19: val_loss improved from 1.09286 to 1.09043, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 61ms/step - loss: 1.0632 - acc: 0.4583 - val_loss: 1.0904 - val_acc: 0.3542
# Epoch 20/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0548 - acc: 0.4250
# Epoch 20: val_loss improved from 1.09043 to 1.08046, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 59ms/step - loss: 1.0507 - acc: 0.4375 - val_loss: 1.0805 - val_acc: 0.5000
# Epoch 21/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0554 - acc: 0.4750
# Epoch 21: val_loss did not improve from 1.08046
# 6/6 [==============================] - 0s 49ms/step - loss: 1.0526 - acc: 0.5000 - val_loss: 1.0805 - val_acc: 0.4583
# Epoch 22/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0366 - acc: 0.4812
# Epoch 22: val_loss did not improve from 1.08046
# 6/6 [==============================] - 0s 51ms/step - loss: 1.0377 - acc: 0.4740 - val_loss: 1.0906 - val_acc: 0.3333
# Epoch 23/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0301 - acc: 0.4938
# Epoch 23: val_loss did not improve from 1.08046
# 6/6 [==============================] - 0s 50ms/step - loss: 1.0333 - acc: 0.4844 - val_loss: 1.0909 - val_acc: 0.3125
# Epoch 24/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0497 - acc: 0.4187
# Epoch 24: val_loss improved from 1.08046 to 1.07602, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 59ms/step - loss: 1.0303 - acc: 0.4583 - val_loss: 1.0760 - val_acc: 0.4375
# Epoch 25/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0150 - acc: 0.5500
# Epoch 25: val_loss improved from 1.07602 to 1.07305, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 60ms/step - loss: 1.0181 - acc: 0.5521 - val_loss: 1.0730 - val_acc: 0.4583
# Epoch 26/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0295 - acc: 0.5188
# Epoch 26: val_loss improved from 1.07305 to 1.06345, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 59ms/step - loss: 1.0262 - acc: 0.5365 - val_loss: 1.0634 - val_acc: 0.4792
# Epoch 27/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0204 - acc: 0.4812
# Epoch 27: val_loss improved from 1.06345 to 1.06251, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 60ms/step - loss: 1.0063 - acc: 0.5104 - val_loss: 1.0625 - val_acc: 0.4583
# Epoch 28/30
# 5/6 [========================>.....] - ETA: 0s - loss: 0.9853 - acc: 0.5312
# Epoch 28: val_loss did not improve from 1.06251
# 6/6 [==============================] - 0s 50ms/step - loss: 1.0123 - acc: 0.4948 - val_loss: 1.0793 - val_acc: 0.3333
# Epoch 29/30
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0046 - acc: 0.5375
# Epoch 29: val_loss improved from 1.06251 to 1.04789, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 59ms/step - loss: 1.0052 - acc: 0.5365 - val_loss: 1.0479 - val_acc: 0.5000
# Epoch 30/30
# 5/6 [========================>.....] - ETA: 0s - loss: 0.9924 - acc: 0.5375
# Epoch 30: val_loss improved from 1.04789 to 1.04737, saving model to ./model\CNN_Cooking.hdf5
# 6/6 [==============================] - 0s 63ms/step - loss: 0.9875 - acc: 0.5260 - val_loss: 1.0474 - val_acc: 0.4792

# %% [markdown]
# ## 5. 모델 평가

# %%
score = model.evaluate(X_test, y_test, verbose=1)
print('정답률 =', score[1], 'loss =', score[0])
# Out:
# 2/2 [==============================] - 0s 12ms/step - loss: 1.0091 - acc: 0.5500
# 정답률 = 0.550000011920929 loss = 1.0090534687042236

# %% [markdown]
# ### 학습 과정 시각화

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
# 학습 상태를 그래프로 그리기 
import matplotlib.pyplot as plt
his_dict = history.history
loss = his_dict['loss']
val_loss = his_dict['val_loss'] 
epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 훈련 및 검증 손실 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['acc']
val_acc = his_dict['val_acc']

# 훈련 및 검증 정확도 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()
plt.show()

# %% [markdown]
# ## 6. 이미지 증식 하기
# - 정답률을 높이기 위해서 데이타 수량을 늘려서 진행
# - 사진을 회전하거나 반전시켜서 데이타 수량을 늘리기

# %% [markdown]
# ### OpenCV를 사용하여 이미지를 0~180도까지 회전
# - opencv-python 모듈 설치 : pip install opencv-python

# %%
import matplotlib.pyplot as plt
import cv2

# 사진 데이터 읽어 들이기
photos = np.load('image/photos.npz')
x = photos['x']
img = x[250] # 사진 하나만 선택하기

plt.figure(figsize=(10,10))
for i in range(36):
    plt.subplot(6,6,i+1)
    # 회전 시키기 
    center = (16, 16) # 회전 중심
    angle = i * 5 # 각도 조정
    scale = 1.0   # 확대 비율
    mtx = cv2.getRotationMatrix2D(center, angle, scale)
    img2 = cv2.warpAffine(img, mtx, (32, 32))
    # 화면에 출력하기
    plt.imshow(img2)
plt.show()

# %% [markdown]
# ## 7. 이미지 증식 후 CNN 모델 학습

# %%
import cnn_model
import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import cv2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os

# 입력과 출력 지정하기
im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

# 사진 데이터 읽어 들이기
photos = np.load('image/photos.npz')
X = photos['x']
y = photos['y']

# X 속성 데이터를 3차원 배열로 변환, 정규화하기
X = x.reshape(-1, im_rows, im_cols, im_color)
X = x.astype('float32') / 255

# 레이블 데이터를 One-hot 형식으로 변환하기
y = to_categorical(y.astype('int32'), nb_classes)

# 학습 전용과 테스트 전용으로 구분하기
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.2,
                                                   random_state=0)

# 검증 데이타 만들기
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2,
                                                  random_state=0)

# 이미지 증식 - 학습 데이타만 적용(주의-테스트 데이타 증식 하지 않는다.)
x_new = []
y_new = []
for i, xi in enumerate(X_train):
    yi = y_train[i]
    for ang in range(-30, 30, 5):
        # 회전 시키기 
        center = (16, 16) # 회전 중심
        mtx = cv2.getRotationMatrix2D(center, ang, 1.0)
        xi2 = cv2.warpAffine(xi, mtx, (32, 32))
        x_new.append(xi2)
        y_new.append(yi)
        # 좌우 반전 
        xi3 = cv2.flip(xi2, 1)
        x_new.append(xi3)
        y_new.append(yi)

# 이미지를 늘린 데이터를 학습 데이터로 사용하기
print('수량을 늘리기 전=', len(y_train))
X_train = np.array(x_new)
y_train = np.array(y_new)
print('수량을 늘린 후=', len(y_train))
print('-'*70)
# Out:
# 수량을 늘리기 전= 192
# 수량을 늘린 후= 4608
# ----------------------------------------------------------------------

# %%
# CNN 모델 만들기 
model = cnn_model.get_model(in_shape, nb_classes)

# ModelCheckpoint, EarlyStopping 지정
# 딥러닝 모델을 저장할 디렉토리(폴더) 생성
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./model/CNN_Cooking2.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# 모델 학습 
history = model.fit(X_train, y_train,
          batch_size=32,
          epochs=30,
          verbose=1,
          validation_data=(X_val, y_val),
          callbacks=[early_stopping_callback, checkpointer])
# Out:
# Epoch 1/30
# 143/144 [============================>.] - ETA: 0s - loss: 1.0878 - acc: 0.3805
# Epoch 1: val_loss improved from inf to 1.10275, saving model to ./model\CNN_Cooking2.hdf5
# 144/144 [==============================] - 7s 43ms/step - loss: 1.0875 - acc: 0.3813 - val_loss: 1.1028 - val_acc: 0.3333
# Epoch 2/30
# 144/144 [==============================] - ETA: 0s - loss: 0.9641 - acc: 0.5263
# Epoch 2: val_loss improved from 1.10275 to 1.04126, saving model to ./model\CNN_Cooking2.hdf5
# 144/144 [==============================] - 6s 42ms/step - loss: 0.9641 - acc: 0.5263 - val_loss: 1.0413 - val_acc: 0.5417
# Epoch 3/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.8402 - acc: 0.6071
# Epoch 3: val_loss did not improve from 1.04126
# 144/144 [==============================] - 6s 42ms/step - loss: 0.8392 - acc: 0.6076 - val_loss: 1.1161 - val_acc: 0.4792
# Epoch 4/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.7678 - acc: 0.6525
# Epoch 4: val_loss did not improve from 1.04126
# 144/144 [==============================] - 6s 42ms/step - loss: 0.7671 - acc: 0.6532 - val_loss: 1.1064 - val_acc: 0.5000
# Epoch 5/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.6868 - acc: 0.6984
# Epoch 5: val_loss did not improve from 1.04126
# 144/144 [==============================] - 6s 41ms/step - loss: 0.6851 - acc: 0.6994 - val_loss: 1.0656 - val_acc: 0.5000
# Epoch 6/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.5900 - acc: 0.7498
# Epoch 6: val_loss did not improve from 1.04126
# 144/144 [==============================] - 6s 42ms/step - loss: 0.5896 - acc: 0.7498 - val_loss: 1.1462 - val_acc: 0.5417
# Epoch 7/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.5163 - acc: 0.7793
# Epoch 7: val_loss did not improve from 1.04126
# 144/144 [==============================] - 6s 42ms/step - loss: 0.5164 - acc: 0.7795 - val_loss: 1.2973 - val_acc: 0.5417
# Epoch 8/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.4758 - acc: 0.8005
# Epoch 8: val_loss did not improve from 1.04126
# 144/144 [==============================] - 5s 36ms/step - loss: 0.4750 - acc: 0.8008 - val_loss: 1.3910 - val_acc: 0.6250
# Epoch 9/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.4042 - acc: 0.8381
# Epoch 9: val_loss did not improve from 1.04126
# 144/144 [==============================] - 5s 36ms/step - loss: 0.4036 - acc: 0.8385 - val_loss: 1.4131 - val_acc: 0.5833
# Epoch 10/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.3602 - acc: 0.8553
# Epoch 10: val_loss did not improve from 1.04126
# 144/144 [==============================] - 5s 34ms/step - loss: 0.3604 - acc: 0.8553 - val_loss: 1.4942 - val_acc: 0.5833
# Epoch 11/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.3378 - acc: 0.8580
# Epoch 11: val_loss did not improve from 1.04126
# 144/144 [==============================] - 5s 34ms/step - loss: 0.3377 - acc: 0.8579 - val_loss: 1.6179 - val_acc: 0.6250
# Epoch 12/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.3112 - acc: 0.8811
# Epoch 12: val_loss did not improve from 1.04126
# 144/144 [==============================] - 5s 34ms/step - loss: 0.3108 - acc: 0.8815 - val_loss: 1.6454 - val_acc: 0.5833

# %% [markdown]
# ### 이미지를 증식한 후 학습한 모델 평가하기

# %%
# 모델 평가하기 
score = model.evaluate(X_test, y_test, verbose=1)
print('정답률 =', score[1], 'loss =', score[0])
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2103 - acc: 0.5833
# 정답률 = 0.5833333134651184 loss = 1.2102775573730469

# %% [markdown]
# ### 학습 과정 시각화

# %%
# 학습 과정 시각화 
import matplotlib.pyplot as plt
his_dict = history.history
loss = his_dict['loss']
val_loss = his_dict['val_loss'] 
epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 학습 및 데트스 손실(loss) 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['acc']
val_acc = his_dict['val_acc']

# 학습 및 데이타 정확도(accuracy) 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()
plt.show()

# %% [markdown]
# ### 모델과 학습된 가중치 데이타 저장하기
# - CNN 모델 저장 => photos-cnn.h5
# - 학습된 데이타 저장 => photos-cnn-weight.hdf5

# %%
# 모델 저장
model.save('./model/photos-cnn-model.h5')

# %%
# 학습된 가중치 데이타 저장
model.save_weights('./model/photos-cnn-weight.hdf5')

# %% [markdown]
# ## 6. CNN 모델 예측하기
# - 직접 찍은 사진으로 테스트 하기
# - 칼로리표
#     - 피자(한조각) : 266 kcal
#     - 스파게티(100g) : 157 kcal
#     - 스시(1인분) : 228 kcal
#
# ### 저장된 모델 및 가중치 불러오기
# -  CNN 모델 읽기
#     - model = load_model('./model/food-cnn.h5')
# - 학습된 가중치 데이타 불러오기
#     - model.load_weights('./model/food-cnn-weight.h5')

# %%
import os
os.getcwd()
# Out:
# 'c:\\python\\딥러닝 실무 프로젝트\\1. CNN_요리이미지분류'

# %%
import cv2
import numpy as np
import tensorflow.keras
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

im_rows = 32
im_cols = 32
in_shape = (im_rows, im_cols, 3)

# 레이블 정보 - 3개 레이블 클래스
labels = ["피자", "스파게티", "스시"]

# CNN 모델 읽기
model = load_model('./model/photos-cnn-model.h5')
# 학습된 데이타 불러오기
model.load_weights('./model/photos-cnn-weight.hdf5')

# OpenCV를 사용해서 이미지 읽어 들이기
im = cv2.imread('./img/test-pizza.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
im = cv2.resize(im, (32, 32))
plt.imshow(im) # 이미지 출력하기
plt.show()

# %%
# 학습한 이미지 데이터에 형태 맞추기
im = im.reshape(in_shape).astype('float32') / 255

# 예측하기
r = model.predict(np.array([im]), batch_size=32,verbose=1)
res = r[0]

# 결과 출력하기
for i, acc in enumerate(res):
    print(labels[i], "=", round(float(acc * 100), 4))
    
print("---"*12)
idx = res.argmax()
per = float(round(res[idx] * 100, 4))
print("예측한 결과 = index :", idx, "\b,", str(round(per,4)) + "%")
# Out:
# 1/1 [==============================] - 0s 87ms/step
# 피자 = 99.1389
# 스파게티 = 0.6162
# 스시 = 0.2449
# ------------------------------------
# 예측한 결과 = index : 0, 99.1389%

# %% [markdown]
# ### 분류된 음식에 칼로리 출력하기

# %%
import cnn_model
import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# target_image = "test-sushi.jpg"

im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

LABELS = ["피자", "스파게티", "스시"] # 레이블의 음식 이름
CALORIES = [266, 157, 228] # 각 레이블별 칼로리

# 저장한 CNN 모델 읽어 들이기
model = load_model('./model/photos-cnn-model.h5')
model.load_weights('./model/photos-cnn-weight.hdf5')

def check_photo(path):
    # 이미지 읽어 들이기
    img = Image.open(path)
    img = img.convert("RGB") # 색공간 변환하기
    img = img.resize((im_cols, im_rows)) # 크기 변경하기
    plt.imshow(img)
    plt.show()
    
    # 3차원으로 데이터 변환하기 + 정규화
    x = np.asarray(img)
    x = x.reshape(-1, im_rows, im_cols, im_color)
    x = x / 255

    # 예측하기
    pre = model.predict([x])[0]
#     print(pre)
    idx = pre.argmax()
    per = int(pre[idx] * 100)
    return (idx, per)

def check_photo_str(path):
    idx, per = check_photo(path)
    # 응답하기
    print("이 사진은", LABELS[idx], "\b로(으로), 칼로리는", CALORIES[idx],"kcal입니다.")
    print("정확도는", per, "%")

# 메인 프로그램
if __name__ == '__main__':
    check_photo_str('./img/test-pizza.jpg')
#     check_photo_str('./test-spaghetti.jpg')
#     check_photo_str('./test-sushi.jpg')
# Out:
# 1/1 [==============================] - 0s 89ms/step
# 이 사진은 피자로(으로), 칼로리는 266 kcal입니다.
# 정확도는 99 %

# %% [markdown]
# ### 예측 결과를 html 파일로 저장하기 --> predict-result.html

# %%
import cnn_model
import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from tensorflow.keras.models import load_model

# target_image = "test-pizza.jpg"

im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

LABELS = ["피자", "스파게티", "스시"] # 레이블의 음식 이름
CALORIES = [266, 157, 228] # 각 레이블별 칼로리

# 저장한 CNN 모델 읽어 들이기
# model = cnn_model.get_model(in_shape, nb_classes)

# CNN 모델 읽기
model = load_model('./model/photos-cnn-model.h5')
# 학습된 데이타 불러오기
model.load_weights('./model/photos-cnn-weight.hdf5')
# M학습한 이미지 데이터에 형태 맞추기
# im = im.reshape(in_shape).astype('float32') / 255

def check_photo(path):
    # 이미지 읽어 들이기
    img = Image.open(path)
    img = img.convert("RGB") # 색공간 변환하기
    img = img.resize((im_cols, im_rows)) # 크기 변경하기
    plt.imshow(img)
    plt.show()
    
    # 데이터 변환하기
    x = np.asarray(img)
    x = x.reshape(-1, im_rows, im_cols, im_color)
    x = x / 255

    # 예측하기
    pre = model.predict([x])[0]
    idx = pre.argmax()
    per = round(float(pre[idx] * 100),3)
    return (idx, per)


result = [] # 여러개의 이미지 파일 예측결과를 리스트로 저장하기
def check_photo_str(path):
    idx, per = check_photo(path)
    # 응답하기
    print("이 사진은", LABELS[idx], "로(으로), 칼로리는", CALORIES[idx],"kcal입니다.")
    print("예측 정확도는", per, "%")
  
    # HTML로 저장하기------------------------------
    # 딥러닝 예측 결과 
    srcfile = path
    html = ""
    html = """<html><head><meta charset="utf8"></head>
    <body><h3>원본 이미지</h3><p>
    <img src='{0}' width=400></p>{1}""".format(path, html)
    
    res = "이 사진은 " + LABELS[idx] + "로(으로), 칼로리는" + str(CALORIES[idx]) +"kcal입니다."
    res = res + "<p>예측 정확도는" + str(per) + "% 입니다.</p><br>"
       
    s = '<div style="float:center;"><p><h3>'+ "<딥러닝 결과> "+'</p></h3><h3>' + res + '</h3>'+ '</div>'
    html += s
    end = "</body></html>"  
    html += end
    print('-'*100)
    print(html)
    print('-'*100)
    result.append(html)
    
    # html을 파일로 저장하기
    with open("./predict-result.html", "w", encoding="utf-8") as f:
        for item in result :
            f.writelines(item)
    print("성공")

if __name__ == '__main__':
    check_photo_str('./img/test-pizza.jpg')
#     check_photo_str('test-spaghetti.jpg')
#     check_photo_str('test-sushi.jpg')
# Out:
# 1/1 [==============================] - 0s 88ms/step
# 이 사진은 피자 로(으로), 칼로리는 266 kcal입니다.
# 예측 정확도는 99.155 %
# ----------------------------------------------------------------------------------------------------
# <html><head><meta charset="utf8"></head>
#     <body><h3>원본 이미지</h3><p>
#     <img src='./img/test-pizza.jpg' width=400></p><div style="float:center;"><p><h3><딥러닝 결과> </p></h3><h3>이 사진은 피자로(으로), 칼로리는266kcal입니다.<p>예측 정확도는99.155% 입니다.</p><br></h3></div></body></html>
# ----------------------------------------------------------------------------------------------------
# 성공
